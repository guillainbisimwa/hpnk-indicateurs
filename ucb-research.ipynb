# %%
import pandas as pd
import io
from datetime import datetime

# %%
mi = pd.read_csv("dataset/research/mi.csv", sep=',') #, encoding='Windows-1252'
# Out:
# /home/guillain/Desktop/python/hpnk-indicateurs/env/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3553: DtypeWarning: Columns (28,29) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
mi.head(50)
# Out:
#                   Date Complété par utilisateur Date de dernière modification  \
# 0   24-12-2019 - 13:28                      Non            24-12-2019 - 13:37
# 1   05-03-2020 - 11:17                      Non            05-03-2020 - 11:35
# 2   18-03-2020 - 12:02                      Oui            18-03-2020 - 12:18
# 3   01-06-2020 - 10:01                      Non            01-06-2020 - 10:14
# 4   01-06-2020 - 10:02                      Non            02-06-2020 - 15:16
# 5   01-06-2020 - 10:13                      Non            01-06-2020 - 10:18
# 6   01-06-2020 - 10:27                      Oui            11-06-2020 - 11:29
# 7   01-06-2020 - 10:31                      Oui            12-06-2020 - 10:41
# 8   01-06-2020 - 10:48                      Non            01-06-2020 - 10:54
# 9   01-06-2020 - 11:25                      Non            01-06-2020 - 11:39
# 10  01-06-2020 - 11:56                      Non            01-06-2020 - 12:02
# ...

# %%
for col in mi.columns: 
    print(col)
# Out:
# Date
# Complété par utilisateur
# Date de dernière modification
# Dernière modification par
# Service
# patient UUID
# Prénom
# Nom
# sexe
# date de naissance
# Origines
# Suivi en ambulatoire
# Visite de contrôle
# Femme enceinte
# Plaintes principales
# Antécédents
# Histoire de la maladie
# Compléments d'anamnèse
# Examen physique
# Diagnostic syndromique (1)
# Hypothèses liées au diagnostic syndromique (1)
# Diagnostic syndromique (2)
# Hypothèses liées au diagnostic syndromique (2)
# Diagnostic syndromique (3)
# Hypothèses liées au diagnostic syndromique (3)
# Diagnostic final
# Diagnostics finaux associés
# Commentaire
# Traitement selon PN
# Evolution
# Unnamed: 30
# Unnamed: 31
# Unnamed: 32
# Unnamed: 33
# Unnamed: 34

# %%
# DELETE ALL NA
mi_clean = mi.fillna("")

# %%
mi_clean.head(50)
# Out:
#                   Date Complété par utilisateur Date de dernière modification  \
# 0   24-12-2019 - 13:28                      Non            24-12-2019 - 13:37
# 1   05-03-2020 - 11:17                      Non            05-03-2020 - 11:35
# 2   18-03-2020 - 12:02                      Oui            18-03-2020 - 12:18
# 3   01-06-2020 - 10:01                      Non            01-06-2020 - 10:14
# 4   01-06-2020 - 10:02                      Non            02-06-2020 - 15:16
# 5   01-06-2020 - 10:13                      Non            01-06-2020 - 10:18
# 6   01-06-2020 - 10:27                      Oui            11-06-2020 - 11:29
# 7   01-06-2020 - 10:31                      Oui            12-06-2020 - 10:41
# 8   01-06-2020 - 10:48                      Non            01-06-2020 - 10:54
# 9   01-06-2020 - 11:25                      Non            01-06-2020 - 11:39
# 10  01-06-2020 - 11:56                      Non            01-06-2020 - 12:02
# ...

# %%
# IMPORT SIGNE VITAUX
signe = pd.read_csv("dataset/research/signe.csv", sep=',') #, encoding='Windows-1252'

# %%
for col in signe.columns: 
    print(col)
# Out:
# Date
# Complété par utilisateur
# Date de dernière modification
# Dernière modification par
# Service
# patient UUID
# Prénom
# Nom
# sexe
# date de naissance
# Origines
# Température (°C)
# Poids (kg)
# Poids (g)
# Taille (cm)
# Tension artérielle (mm Hg)
# Fréquence cardiaque (bat./min)
# Fréquence respiratoire (cycle/min)
# Périmètre crânien (cm)
# Périmètre brachial (cm)
# Périmètre thoracique (cm)
# Pli cutané (cm)

# %%
signe_clean = signe.fillna("")

# %%
signe_clean.head(50)
# Out:
#                   Date Complété par utilisateur Date de dernière modification  \
# 0   06-05-2019 - 12:20                      Oui            06-05-2019 - 12:20
# 1   07-05-2019 - 08:06                      Oui            07-05-2019 - 08:06
# 2   07-05-2019 - 08:08                      Oui            07-05-2019 - 08:10
# 3   07-05-2019 - 08:35                      Oui            07-05-2019 - 08:38
# 4   07-05-2019 - 08:56                      Oui            07-05-2019 - 08:57
# 5   12-07-2019 - 13:42                      Oui            12-07-2019 - 13:45
# 6   12-07-2019 - 14:55                      Oui            12-07-2019 - 14:56
# 7   17-07-2019 - 08:35                      Oui            17-07-2019 - 08:36
# 8   17-07-2019 - 09:01                      Oui            17-07-2019 - 09:01
# 9   21-08-2019 - 13:59                      Oui            21-08-2019 - 13:59
# 10  21-08-2019 - 14:37                      Oui            21-08-2019 - 14:39
# ...
