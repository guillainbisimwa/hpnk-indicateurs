# %%
import pandas as pd
import io

# %%
df1 = pd.read_csv("dataset/orl.csv", sep=";")
#print(df1)

# %%
#df1.head

# %%
row_temp = []
Nom = ''
Postnom = ''
Prénom = ''
time = 0
for index, row in df1.iterrows():
    #print(row.index)
    if time == 0:
        Nom = row.Nom
        Postnom = row.Postnom
        Prénom = row.Prénom
    if row.Nom == Nom and time == 1:
        df1.at[index, 'Nom'] = ""
        df1.at[index, 'Postnom'] = ""
        df1.at[index, 'Prénom'] = ""
        df1.at[index, 'Sexe'] = ""
        df1.at[index, 'Age'] = 0
        df1.at[index, 'Plaintes'] = ""
        df1.at[index, 'Diagnostic final'] = ""
        df1.at[index, 'Diagnostic de présemption'] = ""
        print(Nom)
    else:
        Nom = row.Nom
        Postnom = row.Postnom
        Prénom = row.Prénom
    time = 1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-82-581e19428365> in <module>
#      15         df1.at[index, 'Prénom'] = ""
#      16         df1.at[index, 'Sexe'] = ""
# ---> 17         df1.at[index, 'Age'] = ""
#      18         df1.at[index, 'Plaintes'] = ""
#      19         df1.at[index, 'Diagnostic final'] = ""
#
# ~/Desktop/python/hpnk-indicateurs/env/lib/python3.7/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#    2165             return
#    2166
# -> 2167         return super().__setitem__(key, value)
#    2168
#    2169
#
# ~/Desktop/python/hpnk-indicateurs/env/lib/python3.7/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#    2116             raise ValueError("Not enough indexers for scalar access (setting)!")
#    2117
# -> 2118         self.obj._set_value(*key, value=value, takeable=self._takeable)
#    2119
#    2120
#
# ~/Desktop/python/hpnk-indicateurs/env/lib/python3.7/site-packages/pandas/core/frame.py in _set_value(self, index, col, value, takeable)
#    3268             validate_numeric_casting(series.dtype, value)
#    3269
# -> 3270             series._values[loc] = value
#    3271             # Note: trying to use series._set_value breaks tests in
#    3272             #  tests.frame.indexing.test_indexing and tests.indexing.test_partial
#
# ValueError: invalid literal for int() with base 10: ''

# %%
df1.head(10)
# Out:
#          Date       Nom  Postnom          Prénom Sexe  Age  \
# 0  01-sept-20     mweze    fundi             NaN    M   20
# 1  01-sept-20                                           20
# 2  01-sept-20    zawadi  mustafa             NaN    F   35
# 3  01-sept-20    zawadi  mustafa             NaN    F   35
# 4  01-sept-20  polepole      NaN  Sarah Julienne    F   21
# 5  01-sept-20  polepole      NaN  Sarah Julienne    F   21
# 6  01-sept-20  polepole      NaN  Sarah Julienne    F   21
# 7  02-sept-20     amina   kanega       Henriette    F   18
# 8  02-sept-20     amina   kanega       Henriette    F   18
# 9  02-sept-20     amina   kanega       Henriette    F   18
#
#                   Plaintes            Diagnostic final  \
# 0                  Otalgie               Otite externe
# 1                  Otalgie               Otite externe
# 2  Douleurs de l'ATM droit  Dysfonctionnement de l'ATM
# 3  Douleurs de l'ATM droit  Dysfonctionnement de l'ATM
# 4                Rhinorhée         Rhinosinusite aigue
# 5                Rhinorhée         Rhinosinusite aigue
# 6                Rhinorhée         Rhinosinusite aigue
# 7       Otorrhée/Otorragie     Otite moyenne chronique
# 8       Otorrhée/Otorragie     Otite moyenne chronique
# 9       Otorrhée/Otorragie     Otite moyenne chronique
#
#     Diagnostic de présemption  \
# 0               Otite externe
# 1               Otite externe
# 2  Dysfonctionnement de l'ATM
# 3  Dysfonctionnement de l'ATM
# 4         Rhinosinusite aigue
# 5         Rhinosinusite aigue
# 6         Rhinosinusite aigue
# 7     Otite moyenne chronique
# 8     Otite moyenne chronique
# 9     Otite moyenne chronique
#
#                                         Examens labo Examens imagerie  \
# 0                                                NaN              NaN
# 1                                                NaN              NaN
# 2                                                NaN              NaN
# 3                                                NaN              NaN
# 4                                                NaN              NaN
# 5                                                NaN              NaN
# 6                                                NaN              NaN
# 7  Ecouvillon de l'oreille gauche, Ecouvillon de ...              NaN
# 8  Ecouvillon de l'oreille gauche, Ecouvillon de ...              NaN
# 9  Ecouvillon de l'oreille gauche, Ecouvillon de ...              NaN
#
#                                        Prescriptions           EVT_POSOLOGIE
# 0  Ciprofloxacin 0.3% + dexaméthazone 0.1%, 5ml (...   3X2gouttes / jr/14jrs
# 1  Ciprofloxacin 0.3% + dexaméthazone 0.1%, 5ml (...   3X2gouttes / jr/14jrs
# 2  Vitamine b1 50mg + vitamine b6 50mg + cyanocob...            3x1co/jr/10j
# 3                     Dexaméthazone 0,5mg (Comprimé)           3x2 c/ j/7jrs
# 4  Betaméthazone sodium phosphate 0,1% + néomycin...   3x2gouttes / jr/14jrs
# 5                         Loratadine 10mg (Comprimé)            1co/jr/10jrs
# 6                    Ciprofloxacine 500mg (Comprimé)          2x1co/jr/10jrs
# 7                     Dexaméthazone 0,5mg (Comprimé)           3x2co/jr/7jrs
# 8  Ciprofloxacin 0.3% + dexaméthazone 0.1%, 5ml (...  3x2gouttes / jr/1 mois
# 9                    Ciprofloxacine 500mg (Comprimé)          2x1co/jr/10jrs
