# %%
import pandas as pd
import io
from datetime import datetime

# %%
df1 = pd.read_csv("dataset/ORL201.csv", sep=";", encoding='utf-16')
# Out:
# ---------------------------------------------------------------------------
# UnicodeError                              Traceback (most recent call last)
# <ipython-input-37-af7db8bdce65> in <module>
# ----> 1 df1 = pd.read_csv("dataset/ORL201.csv", sep=";", encoding='utf-16')
#
# ~/Desktop/python/hpnk-indicateurs/env/lib/python3.7/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# ~/Desktop/python/hpnk-indicateurs/env/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# ~/Desktop/python/hpnk-indicateurs/env/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# ~/Desktop/python/hpnk-indicateurs/env/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# ~/Desktop/python/hpnk-indicateurs/env/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1896
#    1897         try:
# -> 1898             self._reader = parsers.TextReader(self.handles.handle, **kwds)
#    1899         except Exception:
#    1900             self.handles.close()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._get_header()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# UnicodeError: UTF-16 stream does not start with BOM

# %%
df1 = df1.fillna("")

# %%
df1.head(10)
# Out:
#          Date      Code       Nom  Postnom          Pr�nom Sexe  Age  \
# 0  01-sept-20               mweze    fundi                    M   21
# 1  01-sept-20  120308.0    zawadi  mustafa                    F   36
# 2  01-sept-20  120308.0    zawadi  mustafa                    F   36
# 3  01-sept-20  120308.0    zawadi  mustafa                    F   36
# 4  01-sept-20            polepole           Sarah Julienne    F   22
# 5  01-sept-20            polepole           Sarah Julienne    F   22
# 6  01-sept-20            polepole           Sarah Julienne    F   22
# 7  02-sept-20  120371.0     amina   kanega       Henriette    F   19
# 8  02-sept-20  120371.0     amina   kanega       Henriette    F   19
# 9  02-sept-20  120371.0     amina   kanega       Henriette    F   19
#
#          NC/AC         Quartier       R�f�rence  ...  \
# 0   Ancien cas   Quartier Himbi                  ...
# 1  Nouveau cas  Quartier Murara       CS Murara  ...
# 2  Nouveau cas  Quartier Murara       CS Murara  ...
# 3  Nouveau cas  Quartier Murara       CS Murara  ...
# 4  Nouveau cas   Quartier Himbi                  ...
# 5  Nouveau cas   Quartier Himbi                  ...
# 6  Nouveau cas   Quartier Himbi                  ...
# 7  Nouveau cas  Quartier Kasika  CSMU Karisimbi  ...
# 8  Nouveau cas  Quartier Kasika  CSMU Karisimbi  ...
# 9  Nouveau cas  Quartier Kasika  CSMU Karisimbi  ...
#
#              Diagnostic final   Diagnostic de pr�semption  \
# 0               Otite externe               Otite externe
# 1  Dysfonctionnement de l'ATM  Dysfonctionnement de l'ATM
# 2  Dysfonctionnement de l'ATM  Dysfonctionnement de l'ATM
# 3  Dysfonctionnement de l'ATM  Dysfonctionnement de l'ATM
# 4         Rhinosinusite aigu�         Rhinosinusite aigu�
# 5         Rhinosinusite aigu�         Rhinosinusite aigu�
# 6         Rhinosinusite aigu�         Rhinosinusite aigu�
# 7     Otite moyenne chronique     Otite moyenne chronique
# 8     Otite moyenne chronique     Otite moyenne chronique
# 9     Otite moyenne chronique     Otite moyenne chronique
#
#                                         Examens labo Examens imagerie  \
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7  Ecouvillon de l'oreille gauche, Ecouvillon de ...
# 8  Ecouvillon de l'oreille gauche, Ecouvillon de ...
# 9  Ecouvillon de l'oreille gauche, Ecouvillon de ...
#
#             ANTECEDANT           HISTOIRE  \
# 0  Polypectomie aurale  Depuis 2 semaines
# 1                            Depuis 2 ans
# 2                            Depuis 2 ans
# 3                            Depuis 2 ans
# 4                       Depuis 3 semaines
# 5                       Depuis 3 semaines
# 6                       Depuis 3 semaines
# 7                             Depuis 1 an
# 8                             Depuis 1 an
# 9                             Depuis 1 an
#
#                                          CPLT ANAMN  \
# 0                                     Pas de fi�vre
# 1  Sensation d'un craquement lors de la mastication
# 2  Sensation d'un craquement lors de la mastication
# 3  Sensation d'un craquement lors de la mastication
# 4                C�phal�es, congestion nasale, toux
# 5                C�phal�es, congestion nasale, toux
# 6                C�phal�es, congestion nasale, toux
# 7    Prurit auriculaire et bourdonnement d'oreilles
# 8    Prurit auriculaire et bourdonnement d'oreilles
# 9    Prurit auriculaire et bourdonnement d'oreilles
#
#                                        EXAM CLINIQUE  \
# 0                                     CAES inflamm�s
# 1        Examen physique de l'ATM sans particularit�
# 2        Examen physique de l'ATM sans particularit�
# 3        Examen physique de l'ATM sans particularit�
# 4  Muqueuse nasale inflamm�e et pr�sence des s�cr...
# 5  Muqueuse nasale inflamm�e et pr�sence des s�cr...
# 6  Muqueuse nasale inflamm�e et pr�sence des s�cr...
# 7          CAES pleins de pus,  tympans non visibles
# 8          CAES pleins de pus,  tympans non visibles
# 9          CAES pleins de pus,  tympans non visibles
#
#                                        Prescriptions               POSOLOGIE
# 0  Ciprofloxacin 0.3% + dexam�thazone 0.1%, 5ml (...     3gouttes / jr/14jrs
# 1                     Dexam�thazone 0,5mg (Comprim�)           3x2 c/ j/7jrs
# 2
# 3  Vitamine b1 50mg + vitamine b6 50mg + cyanocob...            3x1co/jr/10j
# 4                    Ciprofloxacine 500mg (Comprim�)          2x1co/jr/10jrs
# 5                         Loratadine 10mg (Comprim�)            1co/jr/10jrs
# 6  Betam�thazone sodium phosphate 0,1% + n�omycin...   3x2gouttes / jr/14jrs
# 7                     Dexam�thazone 0,5mg (Comprim�)           3x2co/jr/7jrs
# 8  Ciprofloxacin 0.3% + dexam�thazone 0.1%, 5ml (...  3x2gouttes / jr/1 mois
# 9                    Ciprofloxacine 500mg (Comprim�)          2x1co/jr/10jrs
#
# [10 rows x 21 columns]

# %%
row_temp = []
Nom = ''
Postnom = ''
Prénom = ''
time = 0
for index, row in df1.iterrows():
    if time == 0:
        Nom = row.Nom
        Postnom = row.Postnom
        Prénom = row.Prénom
    if row.Nom == Nom and row.Postnom == Postnom and row.Prénom == Prénom and time == 1:
        df1.at[index, 'Date'] = ""
        df1.at[index, 'Nom'] = ""
        df1.at[index, 'Postnom'] = ""
        df1.at[index, 'Prénom'] = ""
        df1.at[index, 'Sexe'] = ""
        df1.at[index, 'Age'] = -1
        df1.at[index, 'Plaintes'] = ""
        df1.at[index, 'Diagnostic final'] = ""
        df1.at[index, 'Diagnostic de présemption'] = ""
        df1.at[index, 'Examens labo'] = ""
    else:
        Nom = row.Nom
        Postnom = row.Postnom
        Prénom = row.Prénom
    time = 1

# %%
df1 = df1.replace(-1, '')
df1.head(10)
# Out:
#          Date       Nom  Postnom          Prénom Sexe Age  \
# 0  01-sept-20     mweze    fundi                    M  20
# 1
# 2  01-sept-20    zawadi  mustafa                    F  35
# 3
# 4  01-sept-20  polepole           Sarah Julienne    F  21
# 5
# 6
# 7  02-sept-20     amina   kanega       Henriette    F  18
# 8
# 9
#
#                   Plaintes            Diagnostic final  \
# 0                  Otalgie               Otite externe
# 1
# 2  Douleurs de l'ATM droit  Dysfonctionnement de l'ATM
# 3
# 4                Rhinorhée         Rhinosinusite aigue
# 5
# 6
# 7       Otorrhée/Otorragie     Otite moyenne chronique
# 8
# 9
#
#     Diagnostic de présemption  \
# 0               Otite externe
# 1
# 2  Dysfonctionnement de l'ATM
# 3
# 4         Rhinosinusite aigue
# 5
# 6
# 7     Otite moyenne chronique
# 8
# 9
#
#                                         Examens labo Examens imagerie  \
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7  Ecouvillon de l'oreille gauche, Ecouvillon de ...
# 8
# 9
#
#                                        Prescriptions           EVT_POSOLOGIE
# 0  Ciprofloxacin 0.3% + dexaméthazone 0.1%, 5ml (...   3X2gouttes / jr/14jrs
# 1  Ciprofloxacin 0.3% + dexaméthazone 0.1%, 5ml (...   3X2gouttes / jr/14jrs
# 2  Vitamine b1 50mg + vitamine b6 50mg + cyanocob...            3x1co/jr/10j
# 3                     Dexaméthazone 0,5mg (Comprimé)           3x2 c/ j/7jrs
# 4  Betaméthazone sodium phosphate 0,1% + néomycin...   3x2gouttes / jr/14jrs
# 5                         Loratadine 10mg (Comprimé)            1co/jr/10jrs
# 6                    Ciprofloxacine 500mg (Comprimé)          2x1co/jr/10jrs
# 7                     Dexaméthazone 0,5mg (Comprimé)           3x2co/jr/7jrs
# 8  Ciprofloxacin 0.3% + dexaméthazone 0.1%, 5ml (...  3x2gouttes / jr/1 mois
# 9                    Ciprofloxacine 500mg (Comprimé)          2x1co/jr/10jrs

# %%
# datetime object containing current date and time
now = datetime.now()
# dd/mm/YY H:M:S
dt_string = now.strftime("%d-%m-%Y-%H-%M-%S-")
df1.to_csv(r'export/'+dt_string+'export.csv')
