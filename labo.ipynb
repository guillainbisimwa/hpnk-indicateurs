# %% [markdown]
# <a href="https://colab.research.google.com/github/guillainbisimwa/hpnk-indicateurs/blob/master/labo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importer un csv

# %%
import pandas as pd
import io

# %%
#from google.colab import files
#uploaded = files.upload()

# %%
#df = pd.read_csv(io.BytesIO(uploaded['labo3.csv'])) 
df = pd.read_csv("dataset/orl.csv", sep=';') 
print(df)
# Out:
#            Date       Nom  Postnom          Prénom Sexe  Age  \
# 0    01-sept-20     mweze    fundi             NaN    M   20
# 1    01-sept-20    zawadi  mustafa             NaN    F   35
# 2    01-sept-20    zawadi  mustafa             NaN    F   35
# 3    01-sept-20  polepole      NaN  Sarah Julienne    F   21
# 4    01-sept-20  polepole      NaN  Sarah Julienne    F   21
# ..          ...       ...      ...             ...  ...  ...
# 345  30-sept-20    kasimu   esther            bibi    F   32
# 346  30-sept-20    kasimu   esther            bibi    F   32
# 347  30-sept-20    kasimu   esther            bibi    F   32
# 348  30-sept-20  Irangaba      NaN          Justin    M   21
# 349  30-sept-20  Irangaba      NaN          Justin    M   21
#
#                     Plaintes            Diagnostic final  \
# 0                    Otalgie               Otite externe
# 1    Douleurs de l'ATM droit  Dysfonctionnement de l'ATM
# 2    Douleurs de l'ATM droit  Dysfonctionnement de l'ATM
# 3                  Rhinorhée         Rhinosinusite aigue
# 4                  Rhinorhée         Rhinosinusite aigue
# ..                       ...                         ...
# 345                  Otalgie            Amygdalite aigue
# 346                  Otalgie            Amygdalite aigue
# 347                  Otalgie            Amygdalite aigue
# 348                  Otalgie         Otite moyenne aigue
# 349                  Otalgie         Otite moyenne aigue
#
#       Diagnostic de présemption Examens labo Examens imagerie  \
# 0                 Otite externe          NaN              NaN
# 1    Dysfonctionnement de l'ATM          NaN              NaN
# 2    Dysfonctionnement de l'ATM          NaN              NaN
# 3           Rhinosinusite aigue          NaN              NaN
# 4           Rhinosinusite aigue          NaN              NaN
# ..                          ...          ...              ...
# 345        Amygdalite chronique          NaN              NaN
# 346        Amygdalite chronique          NaN              NaN
# 347        Amygdalite chronique          NaN              NaN
# 348         Otite moyenne aigue          NaN              NaN
# 349         Otite moyenne aigue          NaN              NaN
#
#                                          Prescriptions          EVT_POSOLOGIE
# 0    Ciprofloxacin 0.3% + dexaméthazone 0.1%, 5ml (...  3X2gouttes / jr/14jrs
# 1    Vitamine b1 50mg + vitamine b6 50mg + cyanocob...           3x1co/jr/10j
# 2                       Dexaméthazone 0,5mg (Comprimé)          3x2 c/ j/7jrs
# 3    Betaméthazone sodium phosphate 0,1% + néomycin...  3x2gouttes / jr/14jrs
# 4                           Loratadine 10mg (Comprimé)           1co/jr/10jrs
# ..                                                 ...                    ...
# 345  acide bêta-glycyrrhétique 60mg  (chlorure de d...  3x1 bouffée / jr/5jrs
# 346                     Dexaméthazone 0,5mg (Comprimé)        3x2co / jr/7jrs
# 347  Ciprofloxacin 0.3% + dexaméthazone 0.1%, 5ml (...  3x2gouttes / jr/14jrs
# 348                    Ciprofloxacine 500mg (Comprimé)         2x1co/jr/10jrs
# 349  Ciprofloxacin 0.3% + dexaméthazone 0.1%, 5ml (...         3x1c/jr/1 mois
#
# [350 rows x 13 columns]

# %%
df.head(10)
# Out:
#             Date     Code  postnom  prenom   <5  nom  Contact patient  \
# 0  2/1/2020 1:55      NaN      NaN     NaN  oui  NaN              NaN
# 1  2/1/2020 7:59      NaN      NaN     NaN  non  NaN              NaN
# 2  2/1/2020 8:01      NaN      NaN     NaN  non  NaN              NaN
# 3  2/1/2020 8:08      NaN      NaN     NaN  non  NaN              NaN
# 4  2/1/2020 8:12      NaN      NaN     NaN  oui  NaN              NaN
# 5  2/1/2020 8:16      NaN      NaN     NaN  non  NaN              NaN
# 6  2/1/2020 8:17      NaN      NaN     NaN  non  NaN              NaN
# 7  2/1/2020 8:22      NaN      NaN     NaN  non  NaN              NaN
# 8  2/1/2020 8:28      NaN      NaN     NaN  oui  NaN              NaN
# 9  2/1/2020 8:31  85268.0      NaN     NaN  non  NaN              NaN
#
#                    Quartier          Avenue  phone  Age Sexe Urgence  \
# 0            Quartier Himbi  présidentielle    NaN    1    M     non
# 1  Territoire de Nyiragongo             NaN    NaN   50    F     non
# 2           Quartier Katoyi             NaN    NaN   39    F     non
# 3          Quartier Katindo      masisi 235    NaN    9    M     non
# 4            Quartier Himbi           uvira    NaN    1    F     non
# 5           Quartier Katoyi             NaN    NaN   22    F     non
# 6          Quartier Mapendo    bweremana 85    NaN   86    M     non
# 7           Quartier Ndosho          lusuli    NaN   25    F     non
# 8          Quartier Virunga     pic boeuf 2    NaN    2    F     non
# 9            Quartier Himbi          alindi    NaN   68    M     non
#
#          NC/AC                                           Plaintes  \
# 0  Nouveau cas  Vomissements plusieurs fois depuis hier, selle...
# 1  Nouveau cas  cervicalgie, nausées, palpitations, lombalgie,...
# 2  Nouveau cas    Céphalées ,vertiges, vision floue, DDR inconnue
# 3  Nouveau cas    dysphagies, fièvre à domicile, anorexie,frisson
# 4  Nouveau cas         congestion nasale, difficulté respiratoire
# 5  Nouveau cas  douleur dentaire, thoracalgie, leucorrhées DDR...
# 6  Nouveau cas                              tumefaction inguinal,
# 7  Nouveau cas  Douleur thoracique, céphalées, douleur articul...
# 8  Nouveau cas        douleur articulaire, rhinorrhées a repetion
# 9   Ancien cas  Céphalées, douleur articulaires, hypogastralgi...
#
#   Service d'orientation   Type de visite Mode de paiement Référence  \
# 0             Pédiatrie  Hospitalisation      Payant cash       non
# 1      Médecine interne     Consultation      Payant cash       oui
# 2      Médecine interne     Consultation      Payant cash       oui
# 3                   ORL              NaN      Payant cash       oui
# 4                   ORL              NaN      Payant cash       oui
# 5           Dentisterie              NaN      Payant cash       oui
# 6             Chirurgie     Consultation      Payant cash       oui
# 7      Médecine interne     Consultation      Payant cash       oui
# 8             Pédiatrie     Consultation      Payant cash       oui
# 9      Médecine interne     Consultation      Payant cash       oui
#
#   Type d'urgence
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN

# %%
examen = df["EVT_TYPE_EXAMEN_VALUE"]
print(examen)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Desktop/python/hpnk-indicateurs/env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'EVT_TYPE_EXAMEN_VALUE'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-e7293c3862a5> in <module>
# ----> 1 examen = df["EVT_TYPE_EXAMEN_VALUE"]
#       2 print(examen)
#
# ~/Desktop/python/hpnk-indicateurs/env/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~/Desktop/python/hpnk-indicateurs/env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'EVT_TYPE_EXAMEN_VALUE'
