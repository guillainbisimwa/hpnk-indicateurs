# %%
import pandas as pd
import io
import numpy as np

# %%
raw = pd.read_csv("dataset/med.csv", sep=',') #  encoding='Windows-1252'

# %%
raw
# Out:
#      cDicCode                                       cDicDesc
# 0        MED1                 Amikacine 1g (Sol. injectable)
# 1       MED10                 Griséofulvine 250mg (Comprimé)
# 2      MED100  Bethamétazone dipropionate 0,05%, 30g (Crème)
# 3     MED1000                                     Céfotaxime
# 4     MED1001                                    Ceftriaxone
# ...       ...                                            ...
# 1347   MED995                                  Aminophylline
# 1348   MED996                                    Ampicilline
# 1349   MED997                                       Atropine
# 1350   MED998       Bupivacaïne (hyperbare, rachianesthésie)
# 1351   MED999                              Calcium gluconate
#
# [1352 rows x 2 columns]

# %%
august = pd.read_csv("dataset/PHARMA/ndAout2022.csv", sep=',') #  encoding='Windows-1252'

# %%
august
# Out:
#        Unnamed: 0                Date  \
# 0               1  01-08-2022 - 10:29
# 1               2  01-08-2022 - 10:30
# 2               3  01-08-2022 - 10:32
# 3               4  01-08-2022 - 10:33
# 4               5  01-08-2022 - 10:34
# ...           ...                 ...
# 10563       11594          12/11/2020
# 10564       11597           9/15/2020
# 10565       11598          12/30/2020
# 10566       11602          12/28/2020
# 10567       11604          12/29/2020
#
#                                           Produit Qt. prescrite  \
# 0                                           Nacl              2
# 1                      Amlodipine 10mg (Comprimé)            10
# 2                  Tétracycline (pde ophtalmique)             2
# 3                                  atrauvastatine            20
# 4      Ceftriaxone, 1g (Pdre pour sol injectable)            10
# ...                                           ...           ...
# 10563                              Acide folique             30
# 10564                         cefixime  co 200mg             10
# 10565                                Ibucap forte            14
# 10566                            pommade Algesal              1
# 10567                                 buscopan co            20
#
#                 Posologie  Qt. dispensée Commentaire        Prénom       Nom  \
# 0           1litre pdt 4h            NaN         NaN           NaN   kasonia
# 1           1co/jr//10jrs            NaN         NaN           NaN   kasonia
# 2                 2x1amp             2.0         NaN        Marie    wabenya
# 3                  2x1ce             0.0         NaN        Marie    wabenya
# 4           2x1g/jr//5jrs            NaN         NaN           NaN   kasonia
# ...                   ...            ...         ...           ...       ...
# 10563            1co/ jr            30.0         NaN    Philomene    BAGUNDA
# 10564  1co x2/ jr //5jrs            10.0         NaN     MBAVUMOJA    KAVIRA
# 10565              2x1gel           14.0         NaN        KAYAYA  KASEREKA
# 10566  3fois par semaine             1.0         NaN  MUNYARIBANJE  SERUKIKO
# 10567                 2x1           20.0         NaN      SEMAHANE     KANGU
#
#       Unnamed: 9
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 10563        NaN
# 10564        NaN
# 10565     Salomo
# 10566        NaN
# 10567    Daniel
#
# [10568 rows x 10 columns]

# %%
print(raw[raw.cDicCode  == "MED99"])
# Out:
#      cDicCode                                cDicDesc
# 1341    MED99  Benzoate de benzyle 25%, 125ml(Lotion)

# %%
row_temp = []
med = ''
for index, row in august.iterrows():
    #august.at[index, 'Produit'] = ""
    line = raw[raw.cDicCode  == row.Produit]
    if line.empty == False:
        val = line.cDicDesc.astype(str)
        #print(val.cDicDesc)
        print(val+" -")
# Out:
# 1047    Amoxicilline 250mg + acide clavulanique 62,5mg...
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 646    Citirizine 1mg/ml (cetrimax) (Sp. orale)
# Name: cDicDesc, dtype: object
# 540    Ciprofloxacine 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 493    Telmisartan 80mg + hydrochlorothiazide 25mg (t...
# Name: cDicDesc, dtype: object
# 434    Solution physiologique (locale), 15ml  (Soluti...
# Name: cDicDesc, dtype: object
# 483    Enalapril 5mg (Comprimé)
# Name: cDicDesc, dtype: object
# 875    Azithromycine 200mg/5ml, 100ml (Poudre pour sp...
# Name: cDicDesc, dtype: object
# 601    Paracétamol + ibuprofène (anaflam, brufen), 10...
# Name: cDicDesc, dtype: object
# 98    Doxycycline
# Name: cDicDesc, dtype: object
# 499    Amlodipine 10mg (Comprimé)
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 432    Protéinate d’argent (argyrol)  0,5 %, 10ml (So...
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 601    Paracétamol + ibuprofène (anaflam, brufen), 10...
# Name: cDicDesc, dtype: object
# 1168    Amoxicilline 500mg + acide clavulanique 50mg (...
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 509    Amoxicilline 250mg/5ml, 100ml  (Pdre pour sp o...
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 493    Telmisartan 80mg + hydrochlorothiazide 25mg (t...
# Name: cDicDesc, dtype: object
# 641    Mephénesine (decontractyl) 250mg (Comprimé)
# Name: cDicDesc, dtype: object
# 647    Desloratadine* 5mg  (Sp. orale)
# Name: cDicDesc, dtype: object
# 499    Amlodipine 10mg (Comprimé)
# Name: cDicDesc, dtype: object
# 614    Amoxicilline  500mg (Gélule)
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 809    Acyclovir 200mg  (Comprimé)
# Name: cDicDesc, dtype: object
# 696    Doxicycline 200mg (Gélule)
# Name: cDicDesc, dtype: object
# 605    Paracétamol 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 1168    Amoxicilline 500mg + acide clavulanique 50mg (...
# Name: cDicDesc, dtype: object
# 540    Ciprofloxacine 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 641    Mephénesine (decontractyl) 250mg (Comprimé)
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 1047    Amoxicilline 250mg + acide clavulanique 62,5mg...
# Name: cDicDesc, dtype: object
# 552    Ciprofloxacine 2mg/ml, 100ml (Infusion iv)
# Name: cDicDesc, dtype: object
# 397    Pommade camphrée 10%, 50g (Pommade)
# Name: cDicDesc, dtype: object
# 462    Spironolactone 25mg (Aldactone) (Comprimé)
# Name: cDicDesc, dtype: object
# 477    Propranolol 40mg (Comprimé)
# Name: cDicDesc, dtype: object
# 447    Mebendazole (vermox) 100mg /5ml (Sp orale)
# Name: cDicDesc, dtype: object
# 702    Zinc sulfate 20mg (Comprimé)
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 695    Omeprazole 20mg + dompéridone 10mg (Prazol D) ...
# Name: cDicDesc, dtype: object
# 499    Amlodipine 10mg (Comprimé)
# Name: cDicDesc, dtype: object
# 630    Ibuprofène 200mg (spedifen) (Comprimé)
# Name: cDicDesc, dtype: object
# 499    Amlodipine 10mg (Comprimé)
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 540    Ciprofloxacine 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 454    Ceftriaxone 1g + tazobactam 125mg (Pdre pour s...
# Name: cDicDesc, dtype: object
# 641    Mephénesine (decontractyl) 250mg (Comprimé)
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 1168    Amoxicilline 500mg + acide clavulanique 50mg (...
# Name: cDicDesc, dtype: object
# 550    Fer + manganèse + cuivre (tot’hema) (Sp. orale)
# Name: cDicDesc, dtype: object
# 655    Montelukast (zopex) 10mg (Comprimé)
# Name: cDicDesc, dtype: object
# 739    Gentamycine 40mg/ml (Sol injectable)
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 606    Paracétamol 150mg/ml  (Sol. injectable)
# Name: cDicDesc, dtype: object
# 1163    Shaltoux
# Name: cDicDesc, dtype: object
# 856    Dextrose 5% iv (serum glucose), 500ml (Infusio...
# Name: cDicDesc, dtype: object
# 605    Paracétamol 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 463    Spironolactone 50mg (Aldactone) (Comprimé)
# Name: cDicDesc, dtype: object
# 397    Pommade camphrée 10%, 50g (Pommade)
# Name: cDicDesc, dtype: object
# 621    Tramadol 37,5mg + paracétamol 325mg (antalgex)...
# Name: cDicDesc, dtype: object
# 721    Antihémorrhoidaire (Suppositoire)
# Name: cDicDesc, dtype: object
# 685    Phloroglycinol 80mg + trimethylphloroglycinol ...
# Name: cDicDesc, dtype: object
# 717    Ondansétron 2mg/ml (anset) (Sol. injectable)
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 462    Spironolactone 25mg (Aldactone) (Comprimé)
# Name: cDicDesc, dtype: object
# 702    Zinc sulfate 20mg (Comprimé)
# Name: cDicDesc, dtype: object
# 601    Paracétamol + ibuprofène (anaflam, brufen), 10...
# Name: cDicDesc, dtype: object
# 1047    Amoxicilline 250mg + acide clavulanique 62,5mg...
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 540    Ciprofloxacine 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 771    Alfuzosin (xatral), 10mg (Comprimé)
# Name: cDicDesc, dtype: object
# 695    Omeprazole 20mg + dompéridone 10mg (Prazol D) ...
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 695    Omeprazole 20mg + dompéridone 10mg (Prazol D) ...
# Name: cDicDesc, dtype: object
# 1023    Levofloxacin 500mg  (Comprimé)
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 614    Amoxicilline  500mg (Gélule)
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 641    Mephénesine (decontractyl) 250mg (Comprimé)
# Name: cDicDesc, dtype: object
# 540    Ciprofloxacine 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 630    Ibuprofène 200mg (spedifen) (Comprimé)
# Name: cDicDesc, dtype: object
# 573    Vitamine b1 50mg + vitamine b6 50mg + cyanocob...
# Name: cDicDesc, dtype: object
# 617    Tramadol 100mg (Comprimé)
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 553    Sérum antitétanique 1500 unités (Sol. injectable)
# Name: cDicDesc, dtype: object
# 417    Cefixime 200mg (Comprimé)
# Name: cDicDesc, dtype: object
# 540    Ciprofloxacine 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 501    Nicardipine 10mg/10ml (Sol. injectable)
# Name: cDicDesc, dtype: object
# 685    Phloroglycinol 80mg + trimethylphloroglycinol ...
# Name: cDicDesc, dtype: object
# 1056    Bande cambrique 10cmx4m (Rouleau)
# Name: cDicDesc, dtype: object
# 606    Paracétamol 150mg/ml  (Sol. injectable)
# Name: cDicDesc, dtype: object
# 695    Omeprazole 20mg + dompéridone 10mg (Prazol D) ...
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 1165    Sparet (goutte)
# Name: cDicDesc, dtype: object
# 493    Telmisartan 80mg + hydrochlorothiazide 25mg (t...
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 499    Amlodipine 10mg (Comprimé)
# Name: cDicDesc, dtype: object
# 409    Nystatine 100000ui (Sp orale)
# Name: cDicDesc, dtype: object
# 641    Mephénesine (decontractyl) 250mg (Comprimé)
# Name: cDicDesc, dtype: object
# 1047    Amoxicilline 250mg + acide clavulanique 62,5mg...
# Name: cDicDesc, dtype: object
# 617    Tramadol 100mg (Comprimé)
# Name: cDicDesc, dtype: object
# 724    Veintonex 480mg (Comprimé)
# Name: cDicDesc, dtype: object
# 1337    Nystatine
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 618    Tramadol 50mg (Comprimé)
# Name: cDicDesc, dtype: object
# 603    Paracétamol + vitamine c (Comprimé efferv.)
# Name: cDicDesc, dtype: object
# 605    Paracétamol 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 1058    Bande élastique 10cmx4m (Rouleau)
# Name: cDicDesc, dtype: object
# 641    Mephénesine (decontractyl) 250mg (Comprimé)
# Name: cDicDesc, dtype: object
# 540    Ciprofloxacine 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 456    Furosémide 10mg/ml (Sol. injectable)
# Name: cDicDesc, dtype: object
# 695    Omeprazole 20mg + dompéridone 10mg (Prazol D) ...
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 463    Spironolactone 50mg (Aldactone) (Comprimé)
# Name: cDicDesc, dtype: object
# 568    Thiamine (vitamine b1) 50mg (Comprimé)
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 568    Thiamine (vitamine b1) 50mg (Comprimé)
# Name: cDicDesc, dtype: object
# 682    Butyl hyoscine bromure (buscopam) 20mg/ml (Sol...
# Name: cDicDesc, dtype: object
# 123    Ibuprofène
# Name: cDicDesc, dtype: object
# 695    Omeprazole 20mg + dompéridone 10mg (Prazol D) ...
# Name: cDicDesc, dtype: object
# 568    Thiamine (vitamine b1) 50mg (Comprimé)
# Name: cDicDesc, dtype: object
# 493    Telmisartan 80mg + hydrochlorothiazide 25mg (t...
# Name: cDicDesc, dtype: object
# 697    Omeprazole 20mg (Comprimé)
# Name: cDicDesc, dtype: object
# 1168    Amoxicilline 500mg + acide clavulanique 50mg (...
# Name: cDicDesc, dtype: object
# 462    Spironolactone 25mg (Aldactone) (Comprimé)
# Name: cDicDesc, dtype: object
# 1168    Amoxicilline 500mg + acide clavulanique 50mg (...
# Name: cDicDesc, dtype: object
# 701    Sels de réhydratation orale (SRO)  (Poudre)
# Name: cDicDesc, dtype: object
# 655    Montelukast (zopex) 10mg (Comprimé)
# Name: cDicDesc, dtype: object
# 458    Furosémide 40mg (Comprimé)
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 501    Nicardipine 10mg/10ml (Sol. injectable)
# Name: cDicDesc, dtype: object
# 409    Nystatine 100000ui (Sp orale)
# Name: cDicDesc, dtype: object
# 641    Mephénesine (decontractyl) 250mg (Comprimé)
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 606    Paracétamol 150mg/ml  (Sol. injectable)
# Name: cDicDesc, dtype: object
# 493    Telmisartan 80mg + hydrochlorothiazide 25mg (t...
# Name: cDicDesc, dtype: object
# 1168    Amoxicilline 500mg + acide clavulanique 50mg (...
# Name: cDicDesc, dtype: object
# 625    Diclofenac 75mg/3ml (Sol. injectable)
# Name: cDicDesc, dtype: object
# 521    Acide acétyle salicylique (aspirine) 100mg (Co...
# Name: cDicDesc, dtype: object
# 695    Omeprazole 20mg + dompéridone 10mg (Prazol D) ...
# Name: cDicDesc, dtype: object
# 696    Doxicycline 200mg (Gélule)
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 641    Mephénesine (decontractyl) 250mg (Comprimé)
# Name: cDicDesc, dtype: object
# 702    Zinc sulfate 20mg (Comprimé)
# Name: cDicDesc, dtype: object
# 1057    Bande de velpeau 10x4m (Rouleau)
# Name: cDicDesc, dtype: object
# 409    Nystatine 100000ui (Sp orale)
# Name: cDicDesc, dtype: object
# 1119    Azythromycine 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 655    Montelukast (zopex) 10mg (Comprimé)
# Name: cDicDesc, dtype: object
# 793    Metformine 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 464    Amoxicilline 500mg + acide clavulanique 62,2 m...
# Name: cDicDesc, dtype: object
# 1119    Azythromycine 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 791    Insuline rapide 100ui/ml (Sol. injectable)
# Name: cDicDesc, dtype: object
# 1100    Seringue luer, 10ml + aig. g21, usage unique (...
# Name: cDicDesc, dtype: object
# 661    Cotrimoxazole 480mg (Bactrim) (Comprimé)
# Name: cDicDesc, dtype: object
# 1165    Sparet (goutte)
# Name: cDicDesc, dtype: object
# 1081    Gants chirurgicaux latex stériles no 7,5 (Paire)
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 499    Amlodipine 10mg (Comprimé)
# Name: cDicDesc, dtype: object
# 618    Tramadol 50mg (Comprimé)
# Name: cDicDesc, dtype: object
# 822    Ciprofloxacin + dexaméthazone (Cifin DX) (Coll...
# Name: cDicDesc, dtype: object
# 641    Mephénesine (decontractyl) 250mg (Comprimé)
# Name: cDicDesc, dtype: object
# 718    Ondansétron 2mg/5ml (anset) (Sp. orale)
# Name: cDicDesc, dtype: object
# 695    Omeprazole 20mg + dompéridone 10mg (Prazol D) ...
# Name: cDicDesc, dtype: object
# 568    Thiamine (vitamine b1) 50mg (Comprimé)
# Name: cDicDesc, dtype: object
# 464    Amoxicilline 500mg + acide clavulanique 62,2 m...
# Name: cDicDesc, dtype: object
# 641    Mephénesine (decontractyl) 250mg (Comprimé)
# Name: cDicDesc, dtype: object
# 499    Amlodipine 10mg (Comprimé)
# Name: cDicDesc, dtype: object
# 521    Acide acétyle salicylique (aspirine) 100mg (Co...
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 614    Amoxicilline  500mg (Gélule)
# Name: cDicDesc, dtype: object
# 695    Omeprazole 20mg + dompéridone 10mg (Prazol D) ...
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 500    Amlodipine 5mg (Comprimé)
# Name: cDicDesc, dtype: object
# 409    Nystatine 100000ui (Sp orale)
# Name: cDicDesc, dtype: object
# 696    Doxicycline 200mg (Gélule)
# Name: cDicDesc, dtype: object
# 641    Mephénesine (decontractyl) 250mg (Comprimé)
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 695    Omeprazole 20mg + dompéridone 10mg (Prazol D) ...
# Name: cDicDesc, dtype: object
# 493    Telmisartan 80mg + hydrochlorothiazide 25mg (t...
# Name: cDicDesc, dtype: object
# 1179    Fluconazole 150mg (Gélule)
# Name: cDicDesc, dtype: object
# 568    Thiamine (vitamine b1) 50mg (Comprimé)
# Name: cDicDesc, dtype: object
# 565    Clarythromycine 125mg/5ml, 100ml* (Pdre pour s...
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 648    Desloratadine* 0,5mg/ml  (Comprimé)
# Name: cDicDesc, dtype: object
# 614    Amoxicilline  500mg (Gélule)
# Name: cDicDesc, dtype: object
# 464    Amoxicilline 500mg + acide clavulanique 62,2 m...
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 1168    Amoxicilline 500mg + acide clavulanique 50mg (...
# Name: cDicDesc, dtype: object
# 493    Telmisartan 80mg + hydrochlorothiazide 25mg (t...
# Name: cDicDesc, dtype: object
# 499    Amlodipine 10mg (Comprimé)
# Name: cDicDesc, dtype: object
# 187    Zinc sulfate (éq. Zinc)
# Name: cDicDesc, dtype: object
# 540    Ciprofloxacine 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 699    Omeprazole 20mg + clarithromycine 250mg + tini...
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 409    Nystatine 100000ui (Sp orale)
# Name: cDicDesc, dtype: object
# 696    Doxicycline 200mg (Gélule)
# Name: cDicDesc, dtype: object
# 744    Acide lactique + extraits naturels (gynokleen,...
# Name: cDicDesc, dtype: object
# 617    Tramadol 100mg (Comprimé)
# Name: cDicDesc, dtype: object
# 536    Acide aminés essentiels + vitamines c et (asty...
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 590    Clarythromycine, 250mg/5ml* (Pdre pour sp orale)
# Name: cDicDesc, dtype: object
# 1062    Bande plâtrée 20 cmx2,7m (Pièce)
# Name: cDicDesc, dtype: object
# 646    Citirizine 1mg/ml (cetrimax) (Sp. orale)
# Name: cDicDesc, dtype: object
# 739    Gentamycine 40mg/ml (Sol injectable)
# Name: cDicDesc, dtype: object
# 699    Omeprazole 20mg + clarithromycine 250mg + tini...
# Name: cDicDesc, dtype: object
# 695    Omeprazole 20mg + dompéridone 10mg (Prazol D) ...
# Name: cDicDesc, dtype: object
# 601    Paracétamol + ibuprofène (anaflam, brufen), 10...
# Name: cDicDesc, dtype: object
# 1057    Bande de velpeau 10x4m (Rouleau)
# Name: cDicDesc, dtype: object
# 1067    Coton hydrophile 500g (Rouleau)
# Name: cDicDesc, dtype: object
# 641    Mephénesine (decontractyl) 250mg (Comprimé)
# Name: cDicDesc, dtype: object
# 462    Spironolactone 25mg (Aldactone) (Comprimé)
# Name: cDicDesc, dtype: object
# 679    Valproate sodique (depakine)  200mg (Capsule o...
# Name: cDicDesc, dtype: object
# 1165    Sparet (goutte)
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 641    Mephénesine (decontractyl) 250mg (Comprimé)
# Name: cDicDesc, dtype: object
# 647    Desloratadine* 5mg  (Sp. orale)
# Name: cDicDesc, dtype: object
# 1345    Ringer lactate (Solution de Hartmann)
# Name: cDicDesc, dtype: object
# 702    Zinc sulfate 20mg (Comprimé)
# Name: cDicDesc, dtype: object
# 688    Phloroglycinol 80mg + trimethylphloroglycinol ...
# Name: cDicDesc, dtype: object
# 655    Montelukast (zopex) 10mg (Comprimé)
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 540    Ciprofloxacine 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 695    Omeprazole 20mg + dompéridone 10mg (Prazol D) ...
# Name: cDicDesc, dtype: object
# 665    Clomipramine (anafranil) 25mg (Comprimé)
# Name: cDicDesc, dtype: object
# 397    Pommade camphrée 10%, 50g (Pommade)
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 695    Omeprazole 20mg + dompéridone 10mg (Prazol D) ...
# Name: cDicDesc, dtype: object
# 704    Zinc sulfate 10mg/5ml (Sp. orale)
# Name: cDicDesc, dtype: object
# 540    Ciprofloxacine 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 552    Ciprofloxacine 2mg/ml, 100ml (Infusion iv)
# Name: cDicDesc, dtype: object
# 1168    Amoxicilline 500mg + acide clavulanique 50mg (...
# Name: cDicDesc, dtype: object
# 620    Artesunate 120mg* (Pdre pour sol. injectable)
# Name: cDicDesc, dtype: object
# 478    Captopril 25mg (Comprimé)
# Name: cDicDesc, dtype: object
# 445    Mebendazole (vermox) 100mg (Comprimé)
# Name: cDicDesc, dtype: object
# 521    Acide acétyle salicylique (aspirine) 100mg (Co...
# Name: cDicDesc, dtype: object
# 540    Ciprofloxacine 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 540    Ciprofloxacine 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 521    Acide acétyle salicylique (aspirine) 100mg (Co...
# Name: cDicDesc, dtype: object
# 856    Dextrose 5% iv (serum glucose), 500ml (Infusio...
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 98    Doxycycline
# Name: cDicDesc, dtype: object
# 647    Desloratadine* 5mg  (Sp. orale)
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 1168    Amoxicilline 500mg + acide clavulanique 50mg (...
# Name: cDicDesc, dtype: object
# 430    Oximethazoline enf. 0,05% (clarinez), 10ml (So...
# Name: cDicDesc, dtype: object
# 621    Tramadol 37,5mg + paracétamol 325mg (antalgex)...
# Name: cDicDesc, dtype: object
# 417    Cefixime 200mg (Comprimé)
# Name: cDicDesc, dtype: object
# 601    Paracétamol + ibuprofène (anaflam, brufen), 10...
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 605    Paracétamol 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 724    Veintonex 480mg (Comprimé)
# Name: cDicDesc, dtype: object
# 606    Paracétamol 150mg/ml  (Sol. injectable)
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 694    Esomeprazole, 20mg (Comprimé)
# Name: cDicDesc, dtype: object
# 619    Tramadol inj, 50mg/ml (Sol injectable)
# Name: cDicDesc, dtype: object
# 499    Amlodipine 10mg (Comprimé)
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 560    Mulitivitamines + sels minéraux (ovacare)  (Gé...
# Name: cDicDesc, dtype: object
# 435    Solution physiologique (sterimar baby), 150dos...
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 145    Paracétamol
# Name: cDicDesc, dtype: object
# 601    Paracétamol + ibuprofène (anaflam, brufen), 10...
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 635    Piroxicam (feldene) 10mg (Comprimé)
# Name: cDicDesc, dtype: object
# 631    Ampicilline  1g  (Pdre pour sol. injectable)
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 739    Gentamycine 40mg/ml (Sol injectable)
# Name: cDicDesc, dtype: object
# 641    Mephénesine (decontractyl) 250mg (Comprimé)
# Name: cDicDesc, dtype: object
# 441    Cefotaxime, 1g (Pdre pour sol injectable)
# Name: cDicDesc, dtype: object
# 617    Tramadol 100mg (Comprimé)
# Name: cDicDesc, dtype: object
# 854    Dextrose 10% iv (serum glucose), 500ml (Infusi...
# Name: cDicDesc, dtype: object
# 540    Ciprofloxacine 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 641    Mephénesine (decontractyl) 250mg (Comprimé)
# Name: cDicDesc, dtype: object
# 454    Ceftriaxone 1g + tazobactam 125mg (Pdre pour s...
# Name: cDicDesc, dtype: object
# 739    Gentamycine 40mg/ml (Sol injectable)
# Name: cDicDesc, dtype: object
# 606    Paracétamol 150mg/ml  (Sol. injectable)
# Name: cDicDesc, dtype: object
# 116    Furosémide
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 463    Spironolactone 50mg (Aldactone) (Comprimé)
# Name: cDicDesc, dtype: object
# 540    Ciprofloxacine 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 1047    Amoxicilline 250mg + acide clavulanique 62,5mg...
# Name: cDicDesc, dtype: object
# 630    Ibuprofène 200mg (spedifen) (Comprimé)
# Name: cDicDesc, dtype: object
# 458    Furosémide 40mg (Comprimé)
# Name: cDicDesc, dtype: object
# 467    Ceftriaxone, 1g (Pdre pour sol injectable)
# Name: cDicDesc, dtype: object
# 601    Paracétamol + ibuprofène (anaflam, brufen), 10...
# Name: cDicDesc, dtype: object
# 714    Dompéridone (motilium) 1mg/ml (Sol. orale)
# Name: cDicDesc, dtype: object
# 739    Gentamycine 40mg/ml (Sol injectable)
# Name: cDicDesc, dtype: object
# 707    Lactulose (duphalac) 200ml (Sol. orale)
# Name: cDicDesc, dtype: object
# 462    Spironolactone 25mg (Aldactone) (Comprimé)
# Name: cDicDesc, dtype: object
# 606    Paracétamol 150mg/ml  (Sol. injectable)
# Name: cDicDesc, dtype: object
# 702    Zinc sulfate 20mg (Comprimé)
# Name: cDicDesc, dtype: object
# 409    Nystatine 100000ui (Sp orale)
# Name: cDicDesc, dtype: object
# 1275    Acide salicylique 2%, 50g (Pommade)
# Name: cDicDesc, dtype: object
# 368    Nystatine 100 000ui/g (Pommade)
# Name: cDicDesc, dtype: object
# 655    Montelukast (zopex) 10mg (Comprimé)
# Name: cDicDesc, dtype: object
# 456    Furosémide 10mg/ml (Sol. injectable)
# Name: cDicDesc, dtype: object
# 641    Mephénesine (decontractyl) 250mg (Comprimé)
# Name: cDicDesc, dtype: object
# 648    Desloratadine* 0,5mg/ml  (Comprimé)
# Name: cDicDesc, dtype: object
# 765    Progestérone (progestogel)  (Crème)
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 463    Spironolactone 50mg (Aldactone) (Comprimé)
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 439    Albendazole 400mg (Comprimé)
# Name: cDicDesc, dtype: object
# 464    Amoxicilline 500mg + acide clavulanique 62,2 m...
# Name: cDicDesc, dtype: object
# 614    Amoxicilline  500mg (Gélule)
# Name: cDicDesc, dtype: object
# 685    Phloroglycinol 80mg + trimethylphloroglycinol ...
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 499    Amlodipine 10mg (Comprimé)
# Name: cDicDesc, dtype: object
# 617    Tramadol 100mg (Comprimé)
# Name: cDicDesc, dtype: object
# 635    Piroxicam (feldene) 10mg (Comprimé)
# Name: cDicDesc, dtype: object
# 697    Omeprazole 20mg (Comprimé)
# Name: cDicDesc, dtype: object
# 430    Oximethazoline enf. 0,05% (clarinez), 10ml (So...
# Name: cDicDesc, dtype: object
# 659    Carbocystéine sp (fluditec) 2%  (Sirop)
# Name: cDicDesc, dtype: object
# 81    Azythromycine
# Name: cDicDesc, dtype: object
# 568    Thiamine (vitamine b1) 50mg (Comprimé)
# Name: cDicDesc, dtype: object
# 462    Spironolactone 25mg (Aldactone) (Comprimé)
# Name: cDicDesc, dtype: object
# 499    Amlodipine 10mg (Comprimé)
# Name: cDicDesc, dtype: object
# 493    Telmisartan 80mg + hydrochlorothiazide 25mg (t...
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 462    Spironolactone 25mg (Aldactone) (Comprimé)
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 601    Paracétamol + ibuprofène (anaflam, brufen), 10...
# Name: cDicDesc, dtype: object
# 1168    Amoxicilline 500mg + acide clavulanique 50mg (...
# Name: cDicDesc, dtype: object
# 536    Acide aminés essentiels + vitamines c et (asty...
# Name: cDicDesc, dtype: object
# 685    Phloroglycinol 80mg + trimethylphloroglycinol ...
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 1168    Amoxicilline 500mg + acide clavulanique 50mg (...
# Name: cDicDesc, dtype: object
# 458    Furosémide 40mg (Comprimé)
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 540    Ciprofloxacine 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 123    Ibuprofène
# Name: cDicDesc, dtype: object
# 478    Captopril 25mg (Comprimé)
# Name: cDicDesc, dtype: object
# 621    Tramadol 37,5mg + paracétamol 325mg (antalgex)...
# Name: cDicDesc, dtype: object
# 718    Ondansétron 2mg/5ml (anset) (Sp. orale)
# Name: cDicDesc, dtype: object
# 64    Amoxycilline
# Name: cDicDesc, dtype: object
# 462    Spironolactone 25mg (Aldactone) (Comprimé)
# Name: cDicDesc, dtype: object
# 1168    Amoxicilline 500mg + acide clavulanique 50mg (...
# Name: cDicDesc, dtype: object
# 5    Ceftriaxone (IM)
# Name: cDicDesc, dtype: object
# 143    Paracétamol
# Name: cDicDesc, dtype: object
# 739    Gentamycine 40mg/ml (Sol injectable)
# Name: cDicDesc, dtype: object
# 428    Oximethazoline ad. 0,1% (clarinez), 10ml (Sol....
# Name: cDicDesc, dtype: object
# 645    Citirizine 10mg (Comprimé)
# Name: cDicDesc, dtype: object
# 685    Phloroglycinol 80mg + trimethylphloroglycinol ...
# Name: cDicDesc, dtype: object
# 697    Omeprazole 20mg (Comprimé)
# Name: cDicDesc, dtype: object
# 854    Dextrose 10% iv (serum glucose), 500ml (Infusi...
# Name: cDicDesc, dtype: object
# 88    Cloxacilline sodique
# Name: cDicDesc, dtype: object
# 973    Erythromycine 250mg (Comprimé)
# Name: cDicDesc, dtype: object
# 656    Salbutamol (ventolin) 100mcg (Aérosol)
# Name: cDicDesc, dtype: object
# 707    Lactulose (duphalac) 200ml (Sol. orale)
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 1047    Amoxicilline 250mg + acide clavulanique 62,5mg...
# Name: cDicDesc, dtype: object
# 618    Tramadol 50mg (Comprimé)
# Name: cDicDesc, dtype: object
# 648    Desloratadine* 0,5mg/ml  (Comprimé)
# Name: cDicDesc, dtype: object
# 641    Mephénesine (decontractyl) 250mg (Comprimé)
# Name: cDicDesc, dtype: object
# 679    Valproate sodique (depakine)  200mg (Capsule o...
# Name: cDicDesc, dtype: object
# 659    Carbocystéine sp (fluditec) 2%  (Sirop)
# Name: cDicDesc, dtype: object
# 718    Ondansétron 2mg/5ml (anset) (Sp. orale)
# Name: cDicDesc, dtype: object
# 423    Fluticasone (avamys) 27.5 µg  (Sol. pulvérisat...
# Name: cDicDesc, dtype: object
# 804    Dexaméthazone 0,5mg (Comprimé)
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 719    Ondansétron 4mg (anset) (Suppositoire)
# Name: cDicDesc, dtype: object
# 44    Quinine dichlorhydrate
# Name: cDicDesc, dtype: object
# 1162    Chlorhéxidine gluconate 0,20% P/V (Hextril ou ...
# Name: cDicDesc, dtype: object
# 702    Zinc sulfate 20mg (Comprimé)
# Name: cDicDesc, dtype: object
# 762    Progestérone  (Sol. injectable)
# Name: cDicDesc, dtype: object
# 614    Amoxicilline  500mg (Gélule)
# Name: cDicDesc, dtype: object
# 88    Cloxacilline sodique
# Name: cDicDesc, dtype: object
# 409    Nystatine 100000ui (Sp orale)
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 603    Paracétamol + vitamine c (Comprimé efferv.)
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 618    Tramadol 50mg (Comprimé)
# Name: cDicDesc, dtype: object
# 695    Omeprazole 20mg + dompéridone 10mg (Prazol D) ...
# Name: cDicDesc, dtype: object
# 695    Omeprazole 20mg + dompéridone 10mg (Prazol D) ...
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 606    Paracétamol 150mg/ml  (Sol. injectable)
# Name: cDicDesc, dtype: object
# 430    Oximethazoline enf. 0,05% (clarinez), 10ml (So...
# Name: cDicDesc, dtype: object
# 540    Ciprofloxacine 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 695    Omeprazole 20mg + dompéridone 10mg (Prazol D) ...
# Name: cDicDesc, dtype: object
# 4    Ceftriaxone
# Name: cDicDesc, dtype: object
# 183    Salbutamol
# Name: cDicDesc, dtype: object
# 696    Doxicycline 200mg (Gélule)
# Name: cDicDesc, dtype: object
# 499    Amlodipine 10mg (Comprimé)
# Name: cDicDesc, dtype: object
# 647    Desloratadine* 5mg  (Sp. orale)
# Name: cDicDesc, dtype: object
# 679    Valproate sodique (depakine)  200mg (Capsule o...
# Name: cDicDesc, dtype: object
# 659    Carbocystéine sp (fluditec) 2%  (Sirop)
# Name: cDicDesc, dtype: object
# 606    Paracétamol 150mg/ml  (Sol. injectable)
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 87    Ciprofloxacine
# Name: cDicDesc, dtype: object
# 541    Acide folique 5mg (Comprimé)
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 718    Ondansétron 2mg/5ml (anset) (Sp. orale)
# Name: cDicDesc, dtype: object
# 1168    Amoxicilline 500mg + acide clavulanique 50mg (...
# Name: cDicDesc, dtype: object
# 695    Omeprazole 20mg + dompéridone 10mg (Prazol D) ...
# Name: cDicDesc, dtype: object
# 647    Desloratadine* 5mg  (Sp. orale)
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 88    Cloxacilline sodique
# Name: cDicDesc, dtype: object
# 648    Desloratadine* 0,5mg/ml  (Comprimé)
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 1168    Amoxicilline 500mg + acide clavulanique 50mg (...
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 1168    Amoxicilline 500mg + acide clavulanique 50mg (...
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 605    Paracétamol 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 695    Omeprazole 20mg + dompéridone 10mg (Prazol D) ...
# Name: cDicDesc, dtype: object
# 695    Omeprazole 20mg + dompéridone 10mg (Prazol D) ...
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 540    Ciprofloxacine 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 641    Mephénesine (decontractyl) 250mg (Comprimé)
# Name: cDicDesc, dtype: object
# 540    Ciprofloxacine 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 699    Omeprazole 20mg + clarithromycine 250mg + tini...
# Name: cDicDesc, dtype: object
# 641    Mephénesine (decontractyl) 250mg (Comprimé)
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 614    Amoxicilline  500mg (Gélule)
# Name: cDicDesc, dtype: object
# 648    Desloratadine* 0,5mg/ml  (Comprimé)
# Name: cDicDesc, dtype: object
# 603    Paracétamol + vitamine c (Comprimé efferv.)
# Name: cDicDesc, dtype: object
# 532    Simvastatine 20mg (Comprimé)
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 464    Amoxicilline 500mg + acide clavulanique 62,2 m...
# Name: cDicDesc, dtype: object
# 814    Nitrofurantoine 100mg (Comprimé)
# Name: cDicDesc, dtype: object
# 664    Arthéméther 180mg + lumefantrine 1080mg/60ml (...
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 682    Butyl hyoscine bromure (buscopam) 20mg/ml (Sol...
# Name: cDicDesc, dtype: object
# 695    Omeprazole 20mg + dompéridone 10mg (Prazol D) ...
# Name: cDicDesc, dtype: object
# 697    Omeprazole 20mg (Comprimé)
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 621    Tramadol 37,5mg + paracétamol 325mg (antalgex)...
# Name: cDicDesc, dtype: object
# 697    Omeprazole 20mg (Comprimé)
# Name: cDicDesc, dtype: object
# 528    Ciprofloxacin*   (Sp orale)
# Name: cDicDesc, dtype: object
# 822    Ciprofloxacin + dexaméthazone (Cifin DX) (Coll...
# Name: cDicDesc, dtype: object
# 540    Ciprofloxacine 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 532    Simvastatine 20mg (Comprimé)
# Name: cDicDesc, dtype: object
# 430    Oximethazoline enf. 0,05% (clarinez), 10ml (So...
# Name: cDicDesc, dtype: object
# 493    Telmisartan 80mg + hydrochlorothiazide 25mg (t...
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 1084    Norfloxacin 100mg + metronidazole 100mg/5ml (n...
# Name: cDicDesc, dtype: object
# 695    Omeprazole 20mg + dompéridone 10mg (Prazol D) ...
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 641    Mephénesine (decontractyl) 250mg (Comprimé)
# Name: cDicDesc, dtype: object
# 664    Arthéméther 180mg + lumefantrine 1080mg/60ml (...
# Name: cDicDesc, dtype: object
# 540    Ciprofloxacine 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 702    Zinc sulfate 20mg (Comprimé)
# Name: cDicDesc, dtype: object
# 695    Omeprazole 20mg + dompéridone 10mg (Prazol D) ...
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 405    Cefixime 100mg/5ml  (Pdre pour sp orale)
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 409    Nystatine 100000ui (Sp orale)
# Name: cDicDesc, dtype: object
# 1047    Amoxicilline 250mg + acide clavulanique 62,5mg...
# Name: cDicDesc, dtype: object
# 699    Omeprazole 20mg + clarithromycine 250mg + tini...
# Name: cDicDesc, dtype: object
# 702    Zinc sulfate 20mg (Comprimé)
# Name: cDicDesc, dtype: object
# 809    Acyclovir 200mg  (Comprimé)
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 647    Desloratadine* 5mg  (Sp. orale)
# Name: cDicDesc, dtype: object
# 809    Acyclovir 200mg  (Comprimé)
# Name: cDicDesc, dtype: object
# 601    Paracétamol + ibuprofène (anaflam, brufen), 10...
# Name: cDicDesc, dtype: object
# 534    Acide aminés essentiels + multivitamines et ol...
# Name: cDicDesc, dtype: object
# 701    Sels de réhydratation orale (SRO)  (Poudre)
# Name: cDicDesc, dtype: object
# 534    Acide aminés essentiels + multivitamines et ol...
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 685    Phloroglycinol 80mg + trimethylphloroglycinol ...
# Name: cDicDesc, dtype: object
# 1168    Amoxicilline 500mg + acide clavulanique 50mg (...
# Name: cDicDesc, dtype: object
# 695    Omeprazole 20mg + dompéridone 10mg (Prazol D) ...
# Name: cDicDesc, dtype: object
# 696    Doxicycline 200mg (Gélule)
# Name: cDicDesc, dtype: object
# 446    Mebendazole (vermox) 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 883    Bicarbonate de sodium 100g (Pdre)
# Name: cDicDesc, dtype: object
# 647    Desloratadine* 5mg  (Sp. orale)
# Name: cDicDesc, dtype: object
# 682    Butyl hyoscine bromure (buscopam) 20mg/ml (Sol...
# Name: cDicDesc, dtype: object
# 1057    Bande de velpeau 10x4m (Rouleau)
# Name: cDicDesc, dtype: object
# 439    Albendazole 400mg (Comprimé)
# Name: cDicDesc, dtype: object
# 702    Zinc sulfate 20mg (Comprimé)
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 540    Ciprofloxacine 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 605    Paracétamol 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 540    Ciprofloxacine 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 540    Ciprofloxacine 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 618    Tramadol 50mg (Comprimé)
# Name: cDicDesc, dtype: object
# 628    Ibuprofène 200mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 447    Mebendazole (vermox) 100mg /5ml (Sp orale)
# Name: cDicDesc, dtype: object
# 618    Tramadol 50mg (Comprimé)
# Name: cDicDesc, dtype: object
# 606    Paracétamol 150mg/ml  (Sol. injectable)
# Name: cDicDesc, dtype: object
# 697    Omeprazole 20mg (Comprimé)
# Name: cDicDesc, dtype: object
# 653    Artesunate 60mg (Pdre pour sol. injectable)
# Name: cDicDesc, dtype: object
# 4    Ceftriaxone
# Name: cDicDesc, dtype: object
# 641    Mephénesine (decontractyl) 250mg (Comprimé)
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 617    Tramadol 100mg (Comprimé)
# Name: cDicDesc, dtype: object
# 685    Phloroglycinol 80mg + trimethylphloroglycinol ...
# Name: cDicDesc, dtype: object
# 641    Mephénesine (decontractyl) 250mg (Comprimé)
# Name: cDicDesc, dtype: object
# 499    Amlodipine 10mg (Comprimé)
# Name: cDicDesc, dtype: object
# 701    Sels de réhydratation orale (SRO)  (Poudre)
# Name: cDicDesc, dtype: object
# 540    Ciprofloxacine 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 1165    Sparet (goutte)
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 1072    Norfloxacin 200mg + metronidazole 200mg (norme...
# Name: cDicDesc, dtype: object
# 717    Ondansétron 2mg/ml (anset) (Sol. injectable)
# Name: cDicDesc, dtype: object
# 747    Clotrimazole (gogynax) (Ovule)
# Name: cDicDesc, dtype: object
# 1096    Ofloxacin 200mg + ornidazole 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 718    Ondansétron 2mg/5ml (anset) (Sp. orale)
# Name: cDicDesc, dtype: object
# 405    Cefixime 100mg/5ml  (Pdre pour sp orale)
# Name: cDicDesc, dtype: object
# 702    Zinc sulfate 20mg (Comprimé)
# Name: cDicDesc, dtype: object
# 439    Albendazole 400mg (Comprimé)
# Name: cDicDesc, dtype: object
# 695    Omeprazole 20mg + dompéridone 10mg (Prazol D) ...
# Name: cDicDesc, dtype: object
# 428    Oximethazoline ad. 0,1% (clarinez), 10ml (Sol....
# Name: cDicDesc, dtype: object
# 439    Albendazole 400mg (Comprimé)
# Name: cDicDesc, dtype: object
# 704    Zinc sulfate 10mg/5ml (Sp. orale)
# Name: cDicDesc, dtype: object
# 1345    Ringer lactate (Solution de Hartmann)
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 605    Paracétamol 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 1348    Ampicilline
# Name: cDicDesc, dtype: object
# 605    Paracétamol 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 699    Omeprazole 20mg + clarithromycine 250mg + tini...
# Name: cDicDesc, dtype: object
# 88    Cloxacilline sodique
# Name: cDicDesc, dtype: object
# 641    Mephénesine (decontractyl) 250mg (Comprimé)
# Name: cDicDesc, dtype: object
# 655    Montelukast (zopex) 10mg (Comprimé)
# Name: cDicDesc, dtype: object
# 618    Tramadol 50mg (Comprimé)
# Name: cDicDesc, dtype: object
# 540    Ciprofloxacine 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 618    Tramadol 50mg (Comprimé)
# Name: cDicDesc, dtype: object
# 4    Ceftriaxone
# Name: cDicDesc, dtype: object
# 839    Povidone iodine 5% (Collyre)
# Name: cDicDesc, dtype: object
# 753    Ampicilline 500mg*  (Pdre pour sol. injectable)
# Name: cDicDesc, dtype: object
# 606    Paracétamol 150mg/ml  (Sol. injectable)
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 763    Métronidazole 250mg (Comprimé)
# Name: cDicDesc, dtype: object
# 540    Ciprofloxacine 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 655    Montelukast (zopex) 10mg (Comprimé)
# Name: cDicDesc, dtype: object
# 4    Ceftriaxone
# Name: cDicDesc, dtype: object
# 756    Nystatine, 100000 ui (Ovule)
# Name: cDicDesc, dtype: object
# 631    Ampicilline  1g  (Pdre pour sol. injectable)
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 532    Simvastatine 20mg (Comprimé)
# Name: cDicDesc, dtype: object
# 713    Dompéridone (motilium) 10mg (Comprimé)
# Name: cDicDesc, dtype: object
# 439    Albendazole 400mg (Comprimé)
# Name: cDicDesc, dtype: object
# 631    Ampicilline  1g  (Pdre pour sol. injectable)
# Name: cDicDesc, dtype: object
# 646    Citirizine 1mg/ml (cetrimax) (Sp. orale)
# Name: cDicDesc, dtype: object
# 739    Gentamycine 40mg/ml (Sol injectable)
# Name: cDicDesc, dtype: object
# 641    Mephénesine (decontractyl) 250mg (Comprimé)
# Name: cDicDesc, dtype: object
# 628    Ibuprofène 200mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 493    Telmisartan 80mg + hydrochlorothiazide 25mg (t...
# Name: cDicDesc, dtype: object
# 717    Ondansétron 2mg/ml (anset) (Sol. injectable)
# Name: cDicDesc, dtype: object
# 467    Ceftriaxone, 1g (Pdre pour sol injectable)
# Name: cDicDesc, dtype: object
# 695    Omeprazole 20mg + dompéridone 10mg (Prazol D) ...
# Name: cDicDesc, dtype: object
# 702    Zinc sulfate 20mg (Comprimé)
# Name: cDicDesc, dtype: object
# 614    Amoxicilline  500mg (Gélule)
# Name: cDicDesc, dtype: object
# 805    Dexaméthazone 4mg/ml, 2ml (Sol. injectable)
# Name: cDicDesc, dtype: object
# 601    Paracétamol + ibuprofène (anaflam, brufen), 10...
# Name: cDicDesc, dtype: object
# 1165    Sparet (goutte)
# Name: cDicDesc, dtype: object
# 646    Citirizine 1mg/ml (cetrimax) (Sp. orale)
# Name: cDicDesc, dtype: object
# 540    Ciprofloxacine 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 641    Mephénesine (decontractyl) 250mg (Comprimé)
# Name: cDicDesc, dtype: object
# 478    Captopril 25mg (Comprimé)
# Name: cDicDesc, dtype: object
# 458    Furosémide 40mg (Comprimé)
# Name: cDicDesc, dtype: object
# 521    Acide acétyle salicylique (aspirine) 100mg (Co...
# Name: cDicDesc, dtype: object
# 601    Paracétamol + ibuprofène (anaflam, brufen), 10...
# Name: cDicDesc, dtype: object
# 462    Spironolactone 25mg (Aldactone) (Comprimé)
# Name: cDicDesc, dtype: object
# 702    Zinc sulfate 20mg (Comprimé)
# Name: cDicDesc, dtype: object
# 854    Dextrose 10% iv (serum glucose), 500ml (Infusi...
# Name: cDicDesc, dtype: object
# 695    Omeprazole 20mg + dompéridone 10mg (Prazol D) ...
# Name: cDicDesc, dtype: object
# 1047    Amoxicilline 250mg + acide clavulanique 62,5mg...
# Name: cDicDesc, dtype: object
# 588    Propofol 10mg/ml (Sp. injectable)
# Name: cDicDesc, dtype: object
# 464    Amoxicilline 500mg + acide clavulanique 62,2 m...
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 690    Amoxicilline 125mg + acide clavulanique 31.25 ...
# Name: cDicDesc, dtype: object
# 1072    Norfloxacin 200mg + metronidazole 200mg (norme...
# Name: cDicDesc, dtype: object
# 405    Cefixime 100mg/5ml  (Pdre pour sp orale)
# Name: cDicDesc, dtype: object
# 446    Mebendazole (vermox) 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 601    Paracétamol + ibuprofène (anaflam, brufen), 10...
# Name: cDicDesc, dtype: object
# 434    Solution physiologique (locale), 15ml  (Soluti...
# Name: cDicDesc, dtype: object
# 409    Nystatine 100000ui (Sp orale)
# Name: cDicDesc, dtype: object
# 601    Paracétamol + ibuprofène (anaflam, brufen), 10...
# Name: cDicDesc, dtype: object
# 695    Omeprazole 20mg + dompéridone 10mg (Prazol D) ...
# Name: cDicDesc, dtype: object
# 569    Thiamine (vitamine b1) 50mg/ml (Sol. injectable)
# Name: cDicDesc, dtype: object
# 695    Omeprazole 20mg + dompéridone 10mg (Prazol D) ...
# Name: cDicDesc, dtype: object
# 540    Ciprofloxacine 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 493    Telmisartan 80mg + hydrochlorothiazide 25mg (t...
# Name: cDicDesc, dtype: object
# 694    Esomeprazole, 20mg (Comprimé)
# Name: cDicDesc, dtype: object
# 718    Ondansétron 2mg/5ml (anset) (Sp. orale)
# Name: cDicDesc, dtype: object
# 695    Omeprazole 20mg + dompéridone 10mg (Prazol D) ...
# Name: cDicDesc, dtype: object
# 682    Butyl hyoscine bromure (buscopam) 20mg/ml (Sol...
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 440    Albendazole 200mg/5ml (Sp orale)
# Name: cDicDesc, dtype: object
# 98    Doxycycline
# Name: cDicDesc, dtype: object
# 701    Sels de réhydratation orale (SRO)  (Poudre)
# Name: cDicDesc, dtype: object
# 1345    Ringer lactate (Solution de Hartmann)
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 702    Zinc sulfate 20mg (Comprimé)
# Name: cDicDesc, dtype: object
# 606    Paracétamol 150mg/ml  (Sol. injectable)
# Name: cDicDesc, dtype: object
# 617    Tramadol 100mg (Comprimé)
# Name: cDicDesc, dtype: object
# 701    Sels de réhydratation orale (SRO)  (Poudre)
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 439    Albendazole 400mg (Comprimé)
# Name: cDicDesc, dtype: object
# 445    Mebendazole (vermox) 100mg (Comprimé)
# Name: cDicDesc, dtype: object
# 718    Ondansétron 2mg/5ml (anset) (Sp. orale)
# Name: cDicDesc, dtype: object
# 797    Fluconazole 50mg/5ml (Sol. orale)
# Name: cDicDesc, dtype: object
# 446    Mebendazole (vermox) 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 606    Paracétamol 150mg/ml  (Sol. injectable)
# Name: cDicDesc, dtype: object
# 540    Ciprofloxacine 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 721    Antihémorrhoidaire (Suppositoire)
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 856    Dextrose 5% iv (serum glucose), 500ml (Infusio...
# Name: cDicDesc, dtype: object
# 695    Omeprazole 20mg + dompéridone 10mg (Prazol D) ...
# Name: cDicDesc, dtype: object
# 949    Ceftazidime 1g* (Pdre pour sol. injectable)
# Name: cDicDesc, dtype: object
# 568    Thiamine (vitamine b1) 50mg (Comprimé)
# Name: cDicDesc, dtype: object
# 1023    Levofloxacin 500mg  (Comprimé)
# Name: cDicDesc, dtype: object
# 534    Acide aminés essentiels + multivitamines et ol...
# Name: cDicDesc, dtype: object
# 617    Tramadol 100mg (Comprimé)
# Name: cDicDesc, dtype: object
# 439    Albendazole 400mg (Comprimé)
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 5    Ceftriaxone (IM)
# Name: cDicDesc, dtype: object
# 690    Amoxicilline 125mg + acide clavulanique 31.25 ...
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 464    Amoxicilline 500mg + acide clavulanique 62,2 m...
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 641    Mephénesine (decontractyl) 250mg (Comprimé)
# Name: cDicDesc, dtype: object
# 540    Ciprofloxacine 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 669    Betahistine (betaserc) 8mg (Comprimé)
# Name: cDicDesc, dtype: object
# 1057    Bande de velpeau 10x4m (Rouleau)
# Name: cDicDesc, dtype: object
# 540    Ciprofloxacine 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 540    Ciprofloxacine 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 540    Ciprofloxacine 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 446    Mebendazole (vermox) 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 499    Amlodipine 10mg (Comprimé)
# Name: cDicDesc, dtype: object
# 493    Telmisartan 80mg + hydrochlorothiazide 25mg (t...
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 641    Mephénesine (decontractyl) 250mg (Comprimé)
# Name: cDicDesc, dtype: object
# 462    Spironolactone 25mg (Aldactone) (Comprimé)
# Name: cDicDesc, dtype: object
# 641    Mephénesine (decontractyl) 250mg (Comprimé)
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 464    Amoxicilline 500mg + acide clavulanique 62,2 m...
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 641    Mephénesine (decontractyl) 250mg (Comprimé)
# Name: cDicDesc, dtype: object
# 695    Omeprazole 20mg + dompéridone 10mg (Prazol D) ...
# Name: cDicDesc, dtype: object
# 696    Doxicycline 200mg (Gélule)
# Name: cDicDesc, dtype: object
# 641    Mephénesine (decontractyl) 250mg (Comprimé)
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 777    Sildénafil 50mg (Comprimé)
# Name: cDicDesc, dtype: object
# 719    Ondansétron 4mg (anset) (Suppositoire)
# Name: cDicDesc, dtype: object
# 579    Vitamines + sels minéraux + antioxydants (lyne...
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 399    Pommade icthiolée, 50g (Pommade)
# Name: cDicDesc, dtype: object
# 429    Cefixime 400mg* (Comprimé)
# Name: cDicDesc, dtype: object
# 601    Paracétamol + ibuprofène (anaflam, brufen), 10...
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 695    Omeprazole 20mg + dompéridone 10mg (Prazol D) ...
# Name: cDicDesc, dtype: object
# 521    Acide acétyle salicylique (aspirine) 100mg (Co...
# Name: cDicDesc, dtype: object
# 478    Captopril 25mg (Comprimé)
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 568    Thiamine (vitamine b1) 50mg (Comprimé)
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 493    Telmisartan 80mg + hydrochlorothiazide 25mg (t...
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 462    Spironolactone 25mg (Aldactone) (Comprimé)
# Name: cDicDesc, dtype: object
# 397    Pommade camphrée 10%, 50g (Pommade)
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 655    Montelukast (zopex) 10mg (Comprimé)
# Name: cDicDesc, dtype: object
# 464    Amoxicilline 500mg + acide clavulanique 62,2 m...
# Name: cDicDesc, dtype: object
# 661    Cotrimoxazole 480mg (Bactrim) (Comprimé)
# Name: cDicDesc, dtype: object
# 540    Ciprofloxacine 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 88    Cloxacilline sodique
# Name: cDicDesc, dtype: object
# 695    Omeprazole 20mg + dompéridone 10mg (Prazol D) ...
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 636    Proxicam (feldene) 20mg (Suppositoire)
# Name: cDicDesc, dtype: object
# 184    Sulfadoxine/Pyriméthamine
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 568    Thiamine (vitamine b1) 50mg (Comprimé)
# Name: cDicDesc, dtype: object
# 540    Ciprofloxacine 500mg (Comprimé)
# Name: cDicDesc, dtype: object
# 679    Valproate sodique (depakine)  200mg (Capsule o...
# Name: cDicDesc, dtype: object
# 499    Amlodipine 10mg (Comprimé)
# Name: cDicDesc, dtype: object
# 641    Mephénesine (decontractyl) 250mg (Comprimé)
# Name: cDicDesc, dtype: object
# 462    Spironolactone 25mg (Aldactone) (Comprimé)
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 464    Amoxicilline 500mg + acide clavulanique 62,2 m...
# Name: cDicDesc, dtype: object
# 297    Compresse, Tulle gras
# Name: cDicDesc, dtype: object
# 521    Acide acétyle salicylique (aspirine) 100mg (Co...
# Name: cDicDesc, dtype: object
# 600    Paracétamol 500mg + ibuprofène 400mg (anaflam)...
# Name: cDicDesc, dtype: object
# 568    Thiamine (vitamine b1) 50mg (Comprimé)
# Name: cDicDesc, dtype: object
