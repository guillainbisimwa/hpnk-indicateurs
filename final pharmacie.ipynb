# %%
import pandas as pd
import io
import numpy as np
from datetime import datetime

# %%
raw = pd.read_csv("dataset/med.csv", sep=',') #  encoding='Windows-1252'

# %%
raw
# Out:
#      cDicCode                                       cDicDesc
# 0        MED1                 Amikacine 1g (Sol. injectable)
# 1       MED10                 Griséofulvine 250mg (Comprimé)
# 2      MED100  Bethamétazone dipropionate 0,05%, 30g (Crème)
# 3     MED1000                                     Céfotaxime
# 4     MED1001                                    Ceftriaxone
# ...       ...                                            ...
# 1347   MED995                                  Aminophylline
# 1348   MED996                                    Ampicilline
# 1349   MED997                                       Atropine
# 1350   MED998       Bupivacaïne (hyperbare, rachianesthésie)
# 1351   MED999                              Calcium gluconate
#
# [1352 rows x 2 columns]

# %%
august = pd.read_csv("export/06-12-2022-14-16-14-pharmacie.csv", sep=',',) #  encoding='Windows-1252'

# %%
august
# Out:
#       Unnamed: 0         Date                       Med  Quant  \
# 0              0  44866.53228          moxyclav duo 1g    14.0
# 1              1  44866.66367             papaverine co   20.0
# 2              2  44867.68773                  fefol co   30.0
# 3              3  44868.44398  paracétamol co 500mg co    10.0
# 4              4  44869.48799             papaverine co   10.0
# ...          ...          ...                       ...    ...
# 8262        8262  44893.50094           paracetamol co    14.0
# 8263        8263  44893.63623             polygel sirop    1.0
# 8264        8264  44893.63578               thiamine co   20.0
# 8265        8265  44894.50448                pylorikit     1.0
# 8266        8266  44895.43069         diprosalic creme     2.0
#
#                      Poso  Quant_d Comment          Nom     PostNom    Prenom
# 0     2x1co/jr pdt 7jr po      0.0     NaN        NZALA      KAMATE  Jacques
# 1                     2x1     20.0     NaN  BAZIRAMWABO  MANIRAGUHA       NaN
# 2                  2x1/ j     30.0     NaN      SABYUNU       SIMBA       NaN
# 3                 2x1co/j     10.0     NaN         JIBU  Christiane   LUNANGA
# 4                   2x1co     10.0     NaN       MUYISA     KAVUGHO       NaN
# ...                   ...      ...     ...          ...         ...       ...
# 8262                 2x1g     14.0     NaN       LOBELA  CHRISTELLE       NaN
# 8263          10ml x3/ jr      1.0     NaN     BYAMUNGU      BIKUBA       NaN
# 8264                  2x1      0.0     NaN       KAHIWA     KATUNGU    Marie
# 8265                 2x3c      1.0    1kit   Emmanuelle    KALONDJI       NaN
# 8266      1appl le matin       0.0     NaN        PUNZA      Marcos    LIBUGE
#
# [8267 rows x 10 columns]

# %%
print(raw[raw.cDicCode  == "MED99"])
# Out:
#      cDicCode                                cDicDesc
# 1341    MED99  Benzoate de benzyle 25%, 125ml(Lotion)

# %%
row_temp = []
med = ''
for index, row in august.iterrows():
   
    line = raw[raw.cDicCode  == row.Med]
    if line.empty == False:
        val = line.cDicDesc.astype(str)
        #val2 = line.cDicDesc.str.split(',') 
        #print(val.cDicDesc)
        #print("#"+val+"#")
        august.at[index, 'Med'] = val

# %%
august
# Out:
#       Unnamed: 0         Date                       Med  Quant  \
# 0              0  44866.53228          moxyclav duo 1g    14.0
# 1              1  44866.66367             papaverine co   20.0
# 2              2  44867.68773                  fefol co   30.0
# 3              3  44868.44398  paracétamol co 500mg co    10.0
# 4              4  44869.48799             papaverine co   10.0
# ...          ...          ...                       ...    ...
# 8262        8262  44893.50094           paracetamol co    14.0
# 8263        8263  44893.63623             polygel sirop    1.0
# 8264        8264  44893.63578               thiamine co   20.0
# 8265        8265  44894.50448                pylorikit     1.0
# 8266        8266  44895.43069         diprosalic creme     2.0
#
#                      Poso  Quant_d Comment          Nom     PostNom    Prenom
# 0     2x1co/jr pdt 7jr po      0.0     NaN        NZALA      KAMATE  Jacques
# 1                     2x1     20.0     NaN  BAZIRAMWABO  MANIRAGUHA       NaN
# 2                  2x1/ j     30.0     NaN      SABYUNU       SIMBA       NaN
# 3                 2x1co/j     10.0     NaN         JIBU  Christiane   LUNANGA
# 4                   2x1co     10.0     NaN       MUYISA     KAVUGHO       NaN
# ...                   ...      ...     ...          ...         ...       ...
# 8262                 2x1g     14.0     NaN       LOBELA  CHRISTELLE       NaN
# 8263          10ml x3/ jr      1.0     NaN     BYAMUNGU      BIKUBA       NaN
# 8264                  2x1      0.0     NaN       KAHIWA     KATUNGU    Marie
# 8265                 2x3c      1.0    1kit   Emmanuelle    KALONDJI       NaN
# 8266      1appl le matin       0.0     NaN        PUNZA      Marcos    LIBUGE
#
# [8267 rows x 10 columns]

# %%
now = datetime.now()
# dd/mm/YY H:M:S
dt_string = now.strftime("%d-%m-%Y-%H-%M-%S-")
august.to_csv(r'export/'+dt_string+'nov-pharmacie.csv')
