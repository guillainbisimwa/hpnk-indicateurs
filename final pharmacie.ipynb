# %%
import pandas as pd
import io
import numpy as np
from datetime import datetime

# %%
raw = pd.read_csv("dataset/med.csv", sep=',') #  encoding='Windows-1252'

# %%
raw
# Out:
#      cDicCode                                       cDicDesc
# 0        MED1                 Amikacine 1g (Sol. injectable)
# 1       MED10                 Griséofulvine 250mg (Comprimé)
# 2      MED100  Bethamétazone dipropionate 0,05%, 30g (Crème)
# 3     MED1000                                     Céfotaxime
# 4     MED1001                                    Ceftriaxone
# ...       ...                                            ...
# 1347   MED995                                  Aminophylline
# 1348   MED996                                    Ampicilline
# 1349   MED997                                       Atropine
# 1350   MED998       Bupivacaïne (hyperbare, rachianesthésie)
# 1351   MED999                              Calcium gluconate
#
# [1352 rows x 2 columns]

# %%
august = pd.read_csv("export/14-03-2023-09-01-31-11-22.csv", sep=',',) #  encoding='Windows-1252'

# %%
august
# Out:
#       Unnamed: 0         Date                Med  Quant               Poso  \
# 0              0  44946.60536         piroxicam    10.0      1x/Jr le soir
# 1              1  44939.56907     shalbactam Tz     6.0                2x1
# 2              2  44953.51309     amlodipine co    30.0                 1x
# 3              3  44953.43104   Decontractyl co    20.0    2x1co par jour
# 4              4  44945.50755     dexeryl creme     1.0    1appl le matin
# ...          ...          ...                ...    ...                ...
# 3795        3795  44935.46287       pd camphree     1.0  2fois par séance
# 3796        3796  44944.40685         pd ibucap     1.0  2fois par séance
# 3797        3797  44924.60512     dexeryl crème     1.0     1app le matin
# 3798        3798  44936.51660  ibucap forte cap    14.0             2x2cap
# 3799        3799  44936.51678       combiart co    24.0   2x4co/jr//3 jrs
#
#       Quant_d                  Comment         Nom       PostNom     Prenom  \
# 0        10.0  piroxicam suppositoire      WILONJA       Sophie         NaN
# 1         0.0                      NaN       MIHIO        KUBUYA        NaN
# 2        30.0                      NaN     MAISAVE        BAHATI        NaN
# 3        20.0                      NaN  Immaculée     KANYAMANZA        NaN
# 4         1.0                      NaN      KAKALA         Attie        NaN
# ...       ...                      ...         ...           ...        ...
# 3795      0.0                      NaN     Astrida  M KAJIBWAMI         NaN
# 3796      1.0                      NaN     Astrida  M KAJIBWAMI         NaN
# 3797      1.0                      NaN      ZIREZE     KAJIBWAMI  Prescilia
# 3798     14.0                      NaN     BULAMBO        NGANDU     GLOIRE
# 3799     24.0                      NaN     BULAMBO        NGANDU     GLOIRE
#
#      cPAT_Genre  cPAT_DDN
# 0             F  19950519
# 1             M  19840401
# 2             M  19810304
# 3             F  19510101
# 4             F  20201230
# ...         ...       ...
# 3795          F  19520101
# 3796          F  19520101
# 3797          F  20180121
# 3798          M  20070917
# 3799          M  20070917
#
# [3800 rows x 12 columns]

# %%
print(raw[raw.cDicCode  == "MED99"])
# Out:
#      cDicCode                                cDicDesc
# 1341    MED99  Benzoate de benzyle 25%, 125ml(Lotion)

# %%
row_temp = []
med = ''
for index, row in august.iterrows():
   
    line = raw[raw.cDicCode  == row.Med]
    if line.empty == False:
        val = line.cDicDesc.astype(str)
        #val2 = line.cDicDesc.str.split(',') 
        #print(val.cDicDesc)
        #print("#"+val+"#")
        august.at[index, 'Med'] = val

# %%
august
# Out:
#       Unnamed: 0         Date                Med  Quant               Poso  \
# 0              0  44946.60536         piroxicam    10.0      1x/Jr le soir
# 1              1  44939.56907     shalbactam Tz     6.0                2x1
# 2              2  44953.51309     amlodipine co    30.0                 1x
# 3              3  44953.43104   Decontractyl co    20.0    2x1co par jour
# 4              4  44945.50755     dexeryl creme     1.0    1appl le matin
# ...          ...          ...                ...    ...                ...
# 3795        3795  44935.46287       pd camphree     1.0  2fois par séance
# 3796        3796  44944.40685         pd ibucap     1.0  2fois par séance
# 3797        3797  44924.60512     dexeryl crème     1.0     1app le matin
# 3798        3798  44936.51660  ibucap forte cap    14.0             2x2cap
# 3799        3799  44936.51678       combiart co    24.0   2x4co/jr//3 jrs
#
#       Quant_d                  Comment         Nom       PostNom     Prenom  \
# 0        10.0  piroxicam suppositoire      WILONJA       Sophie         NaN
# 1         0.0                      NaN       MIHIO        KUBUYA        NaN
# 2        30.0                      NaN     MAISAVE        BAHATI        NaN
# 3        20.0                      NaN  Immaculée     KANYAMANZA        NaN
# 4         1.0                      NaN      KAKALA         Attie        NaN
# ...       ...                      ...         ...           ...        ...
# 3795      0.0                      NaN     Astrida  M KAJIBWAMI         NaN
# 3796      1.0                      NaN     Astrida  M KAJIBWAMI         NaN
# 3797      1.0                      NaN      ZIREZE     KAJIBWAMI  Prescilia
# 3798     14.0                      NaN     BULAMBO        NGANDU     GLOIRE
# 3799     24.0                      NaN     BULAMBO        NGANDU     GLOIRE
#
#      cPAT_Genre  cPAT_DDN
# 0             F  19950519
# 1             M  19840401
# 2             M  19810304
# 3             F  19510101
# 4             F  20201230
# ...         ...       ...
# 3795          F  19520101
# 3796          F  19520101
# 3797          F  20180121
# 3798          M  20070917
# 3799          M  20070917
#
# [3800 rows x 12 columns]

# %%
now = datetime.now()
# dd/mm/YY H:M:S
dt_string = now.strftime("%d-%m-%Y-%H-%M-%S-")
august.to_csv(r'export/'+dt_string+'pharma-1-23.csv')
