# %%
import pandas as pd
import io
import numpy as np
from datetime import datetime

# %%
raw = pd.read_csv("dataset/med.csv", sep=',') #  encoding='Windows-1252'

# %%
raw
# Out:
#      cDicCode                                       cDicDesc
# 0        MED1                 Amikacine 1g (Sol. injectable)
# 1       MED10                 Griséofulvine 250mg (Comprimé)
# 2      MED100  Bethamétazone dipropionate 0,05%, 30g (Crème)
# 3     MED1000                                     Céfotaxime
# 4     MED1001                                    Ceftriaxone
# ...       ...                                            ...
# 1347   MED995                                  Aminophylline
# 1348   MED996                                    Ampicilline
# 1349   MED997                                       Atropine
# 1350   MED998       Bupivacaïne (hyperbare, rachianesthésie)
# 1351   MED999                              Calcium gluconate
#
# [1352 rows x 2 columns]

# %%
august = pd.read_csv("export/05-01-2023-13-50-37-pharmacie-12.csv", sep=',',) #  encoding='Windows-1252'

# %%
august
# Out:
#       Unnamed: 0         Date                       Med  Quant  \
# 0              0  44901,81514         cefixime co 200mg   20.0
# 1              1   44902,5986      albendazol co 400mg     1.0
# 2              2  44902,57854  paracétamol co 500mg co    20.0
# 3              3  44903,54063        omeprazol co 20mg    10.0
# 4              4  44903,61654                        RL    2.0
# ...          ...          ...                       ...    ...
# 5736        5736  44902,58317      levofloxane co 500mg   10.0
# 5737        5737  44907,58196                   MED1238    1.0
# 5738        5738  44154,54781     azithromycine co 5mg     6.0
# 5739        5739  44907,58118                    MED771    1.0
# 5740        5740  44907,58006                    MED268   20.0
#
#                            Poso  Quant_d Comment          Nom      PostNom  \
# 0                      2×2co/jr     20.0     NaN    CONSTANCE  UZAMUKUNDA
# 1                     1co po DU      1.0     NaN       Josué         WASSO
# 2                      2x2co /j     20.0     NaN      NDAGANO     Laureine
# 3     1co par j po pdt 10jours      10.0     NaN  CHIRIMWAMI         David
# 4     500ml+3amp de spasfon//4h      0.0     NaN      luumyo         JOËL
# ...                         ...      ...     ...          ...          ...
# 5736                         1x     10.0     NaN       MALIRO         BIRA
# 5737                          1      1.0     NaN       tsongo      kambale
# 5738                        1ce      6.0   500mg      MASTAKI       MASIKA
# 5739                          1      1.0     NaN       tsongo      kambale
# 5740            2x1co par jour      20.0     NaN       tsongo      kambale
#
#        Prenom
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...
# 5736      NaN
# 5737      NaN
# 5738  FRANCKY
# 5739      NaN
# 5740      NaN
#
# [5741 rows x 10 columns]

# %%
print(raw[raw.cDicCode  == "MED99"])
# Out:
#      cDicCode                                cDicDesc
# 1341    MED99  Benzoate de benzyle 25%, 125ml(Lotion)

# %%
row_temp = []
med = ''
for index, row in august.iterrows():
   
    line = raw[raw.cDicCode  == row.Med]
    if line.empty == False:
        val = line.cDicDesc.astype(str)
        #val2 = line.cDicDesc.str.split(',') 
        #print(val.cDicDesc)
        #print("#"+val+"#")
        august.at[index, 'Med'] = val

# %%
august
# Out:
#       Unnamed: 0         Date  \
# 0              0  44901,81514
# 1              1   44902,5986
# 2              2  44902,57854
# 3              3  44903,54063
# 4              4  44903,61654
# ...          ...          ...
# 5736        5736  44902,58317
# 5737        5737  44907,58196
# 5738        5738  44154,54781
# 5739        5739  44907,58118
# 5740        5740  44907,58006
#
#                                                     Med  Quant  \
# 0                                     cefixime co 200mg   20.0
# 1                                  albendazol co 400mg     1.0
# 2                              paracétamol co 500mg co    20.0
# 3                                    omeprazol co 20mg    10.0
# 4                                                    RL    2.0
# ...                                                 ...    ...
# 5736                               levofloxane co 500mg   10.0
# 5737  266    Sonde vésicale à ballonnet (Foley)
# Name...    1.0
# 5738                              azithromycine co 5mg     6.0
# 5739  1099    Sac à urine stérile, 1,5/2l avec valve...    1.0
# 5740  540    Ciprofloxacine 500mg (Comprimé)
# Name: c...   20.0
#
#                            Poso  Quant_d Comment          Nom      PostNom  \
# 0                      2×2co/jr     20.0     NaN    CONSTANCE  UZAMUKUNDA
# 1                     1co po DU      1.0     NaN       Josué         WASSO
# 2                      2x2co /j     20.0     NaN      NDAGANO     Laureine
# 3     1co par j po pdt 10jours      10.0     NaN  CHIRIMWAMI         David
# 4     500ml+3amp de spasfon//4h      0.0     NaN      luumyo         JOËL
# ...                         ...      ...     ...          ...          ...
# 5736                         1x     10.0     NaN       MALIRO         BIRA
# 5737                          1      1.0     NaN       tsongo      kambale
# 5738                        1ce      6.0   500mg      MASTAKI       MASIKA
# 5739                          1      1.0     NaN       tsongo      kambale
# 5740            2x1co par jour      20.0     NaN       tsongo      kambale
#
#        Prenom
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...
# 5736      NaN
# 5737      NaN
# 5738  FRANCKY
# 5739      NaN
# 5740      NaN
#
# [5741 rows x 10 columns]

# %%
now = datetime.now()
# dd/mm/YY H:M:S
dt_string = now.strftime("%d-%m-%Y-%H-%M-%S-")
august.to_csv(r'export/'+dt_string+'pharma-12.csv')
